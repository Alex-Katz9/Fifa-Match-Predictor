# %%
import pandas as pd
import sqlite3

# %%
con = sqlite3.connect("database.sqlite")
df = pd.read_sql_query("SELECT * from football_data", con)
# print(df.head())
df.columns
# Out:
# Index(['Season', 'Datetime', 'Div', 'Country', 'League', 'Referee', 'HomeTeam',
#        'AwayTeam', 'FTHG', 'FTAG',
#        ...
#        'VCCD', 'VCCH', 'VCD', 'VCH', 'WHA', 'WHCA', 'WHCD', 'WHCH', 'WHD',
#        'WHH'],
#       dtype='object', length=172)

# %%
print(df.head())
# Out:
#       Season             Datetime  Div   Country                    League  \
# 0  2020/2021  2021-02-09 03:00:00  MEX    Mexico                   Liga MX
# 1       2020  2021-02-08 23:00:00  BRA    Brazil                   Serie A
# 2  2020/2021  2021-02-08 21:00:00   P1  Portugal                    Liga I
# 3  2020/2021  2021-02-08 20:00:00  SP2     Spain  La Liga Segunda Division
# 4  2020/2021  2021-02-08 20:00:00   E0   England            Premier League
#
#       Referee     HomeTeam            AwayTeam  FTHG  FTAG  ... VCCD  VCCH  \
# 0        None    Club Leon  Guadalajara Chivas     1     3  ...  NaN   NaN
# 1        None  Botafogo RJ              Gremio     2     5  ...  NaN   NaN
# 2        None   Belenenses           Guimaraes     1     1  ...  3.0   3.0
# 3        None         Lugo             Espanol     1     1  ...  3.4   5.5
# 4  A Marriner        Leeds      Crystal Palace     2     0  ...  3.7   1.8
#
#    VCD   VCH   WHA  WHCA  WHCD  WHCH  WHD   WHH
# 0  NaN   NaN   NaN   NaN   NaN   NaN  NaN   NaN
# 1  NaN   NaN   NaN   NaN   NaN   NaN  NaN   NaN
# 2  3.2  3.13  2.25  2.55  3.00  3.00  3.2  3.30
# 3  3.0  4.20  2.05  1.70  3.20  5.80  2.9  4.20
# 4  3.8  1.85  4.00  4.50  3.75  1.78  3.8  1.85
#
# [5 rows x 172 columns]

# %%
games_df = pd.DataFrame()
games_df['Season'] = df['Season']
games_df['Datetime'] = df['Datetime']
games_df['League'] = df['League']
games_df['HomeTeam'] = df['HomeTeam']
games_df['AwayTeam'] = df['AwayTeam']
games_df['FTHG'] = df['FTHG']
games_df['FTAG'] = df['FTAG']
games_df['Hwinodds'] = df['B365H']
games_df['Dodds'] = df['B365D']
games_df['Awinodds'] = df['B365A']


games_df.head()
# Out:
#       Season             Datetime                    League     HomeTeam  \
# 0  2020/2021  2021-02-09 03:00:00                   Liga MX    Club Leon
# 1       2020  2021-02-08 23:00:00                   Serie A  Botafogo RJ
# 2  2020/2021  2021-02-08 21:00:00                    Liga I   Belenenses
# 3  2020/2021  2021-02-08 20:00:00  La Liga Segunda Division         Lugo
# 4  2020/2021  2021-02-08 20:00:00            Premier League        Leeds
#
#              AwayTeam  FTHG  FTAG  Hwinodds  Dodds  Awinodds
# 0  Guadalajara Chivas     1     3       NaN    NaN       NaN
# 1              Gremio     2     5       NaN    NaN       NaN
# 2           Guimaraes     1     1      3.20    3.2      2.25
# 3             Espanol     1     1      4.75    2.9      1.95
# 4      Crystal Palace     2     0      1.80    3.8      4.20

# %%
games_df['League'].unique()
# Out:
# array(['Liga MX', 'Serie A', 'Liga I', 'La Liga Segunda Division',
#        'Premier League', 'La Liga Primera Division', 'Bundesliga 2',
#        'Liga 1', 'Superliga', 'Ethniki Katigoria', 'Futbol Ligi 1',
#        'Le Championnat', 'Serie B', 'Jupiler League', 'Ekstraklasa',
#        'Super League', 'Bundesliga 1', 'Conference', 'Division 1',
#        'Eredivisie', 'Championship', 'League 1', 'League 2', 'Division 2',
#        'Bundesliga', 'Primera Division', 'Division 3', 'Eliteserien',
#        'Allsvenskan', 'MLS', 'Veikkausliiga', 'J-League',
#        'Premier Division'], dtype=object)

# %%
french = games_df[games_df['League'] == 'La Liga Primera Division']
french['HomeTeam'].unique()
# Out:
# array(['Ath Madrid', 'Betis', 'Osasuna', 'Ath Bilbao', 'Sociedad',
#        'Sevilla', 'Elche', 'Huesca', 'Levante', 'Alaves', 'Barcelona',
#        'Granada', 'Cadiz', 'Getafe', 'Villarreal', 'Valencia',
#        'Real Madrid', 'Eibar', 'Valladolid', 'Celta', 'Espanol',
#        'Leganes', 'Mallorca', 'Girona', 'Vallecano', 'Malaga',
#        'Las Palmas', 'La Coruna', 'Sp Gijon', 'Almeria', 'Cordoba',
#        'Zaragoza', 'Santander', 'Hercules', 'Xerez', 'Tenerife',
#        'Numancia', 'Recreativo', 'Murcia', 'Gimnastic', 'Albacete',
#        'Oviedo'], dtype=object)

# %% [markdown]
# # Filter game to just top 5 Leagues in Europe (English, Spanish, German, Italian, French)

# %%
games_top = games_df[(games_df['League'] == 'Serie A') | (games_df['League'] == 'Premier League') | (games_df['League'] == 'Le Championnat') | (games_df['League'] == 'La Liga Primera Division') | (games_df['League'] == 'Bundesliga 1')] 
games_top.shape
games_top1= games_top.copy()
games_top1= games_top[(games_top['Season'] == '2014/2015') | (games_top['Season'] == '2015/2016') | (games_top['Season'] == '2016/2017') | (games_top['Season'] == '2017/2018') | (games_top['Season'] == '2018/2019') | (games_top['Season'] == '2019/2020') | (games_top['Season'] == '2020/2021')] 

# English Premier League (EPL) 30 of 30.
# La Liga (Spain) 29 of 30. ...
# Fußball-Bundesliga (Germany) 28 of 30. ...
# Serie A (Italy) 27 of 30. ...
# Ligue 1 (France)
games_top1
# Out:
#           Season             Datetime                    League  \
# 4      2020/2021  2021-02-08 20:00:00            Premier League
# 5      2020/2021  2021-02-08 20:00:00  La Liga Primera Division
# 19     2020/2021  2021-02-07 20:00:00            Le Championnat
# 20     2020/2021  2021-02-07 20:00:00  La Liga Primera Division
# 23     2020/2021  2021-02-07 19:45:00                   Serie A
# ...          ...                  ...                       ...
# 77350  2014/2015  2014-08-03 13:30:00            Premier League
# 77381  2014/2015  2014-08-02 18:30:00            Premier League
# 77389  2014/2015  2014-08-02 16:00:00            Premier League
# 77398  2014/2015  2014-08-02 13:30:00            Premier League
# 77431  2014/2015  2014-08-01 17:00:00            Premier League
#
#             HomeTeam        AwayTeam  FTHG  FTAG  Hwinodds  Dodds  Awinodds
# 4              Leeds  Crystal Palace     2     0      1.80    3.8       4.2
# 5         Ath Madrid           Celta     2     2      1.60    3.6       6.5
# 19         Marseille        Paris SG     0     2      7.50    5.0       1.4
# 20             Betis       Barcelona     2     3      5.75    4.6       1.5
# 23             Lazio        Cagliari     1     0      1.36    5.0       8.0
# ...              ...             ...   ...   ...       ...    ...       ...
# 77350  Dynamo Moscow       FK Rostov     7     3       NaN    NaN       NaN
# 77381    CSKA Moscow       T. Moscow     4     1       NaN    NaN       NaN
# 77389   Arsenal Tula           Zenit     0     4       NaN    NaN       NaN
# 77398           Ural      M. Saransk     2     3       NaN    NaN       NaN
# 77431    Rubin Kazan  Spartak Moscow     0     4       NaN    NaN       NaN
#
# [15014 rows x 10 columns]

# %%
# games_test = games_top.dropna(thresh=2, inplace=True)
# games_test
games_nonull = games_top1[games_top1.Hwinodds.notnull()]
games_nonull
games_nonull.to_pickle("./all_games.pkl")

# %%
fif15 = pd.read_csv("players_15.csv")  
fif16 = pd.read_csv("players_16.csv")
fif17 = pd.read_csv("players_17.csv") 
fif18 = pd.read_csv("players_18.csv")
fif19 = pd.read_csv("players_19.csv")
fif20 = pd.read_csv("players_20.csv")
fif21 = pd.read_csv("players_21.csv")
# teams_leagues = pd.read_csv('teams_and_leagues.csv')

# %%
pd.set_option('display.max_columns', None)

fif15['league_name'].unique
# Out:
# <bound method Series.unique of 0             Spain Primera Division
# 1             Spain Primera Division
# 2               German 1. Bundesliga
# 3                     French Ligue 1
# 4               German 1. Bundesliga
#                     ...
# 16150             English League Two
# 16151             English League Two
# 16152    Polish T-Mobile Ekstraklasa
# 16153             English League One
# 16154             English League Two
# Name: league_name, Length: 16155, dtype: object>

# %%
Barc_14_15= fif15[fif15['club_name'] == "FC Barcelona"]

Barc_14_15.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club_name',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=106)

# %%
fif15_j= fif15.copy()
fif16_j= fif16.copy()
fif17_j= fif17.copy()
fif18_j= fif18.copy()
fif19_j= fif19.copy()
fif20_j= fif20.copy()
fif21_j= fif21.copy()
pd.set_option('display.max_columns', None)
fif15_j.head(5)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4     167495  https://sofifa.com/player/167495/manuel-neuer/...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  1985-02-05
# 2          A. Robben                         Arjen Robben   30  1984-01-23
# 3     Z. Ibrahimović                   Zlatan Ibrahimović   32  1981-10-03
# 4           M. Neuer                         Manuel Neuer   28  1986-03-27
#
#    height_cm  weight_kg  nationality            club_name  \
# 0        169         67    Argentina         FC Barcelona
# 1        185         80     Portugal          Real Madrid
# 2        180         80  Netherlands    FC Bayern München
# 3        195         95       Sweden  Paris Saint-Germain
# 4        193         92      Germany    FC Bayern München
#
#               league_name  league_rank  overall  potential  value_eur  \
# 0  Spain Primera Division          1.0       93         95  100500000
# 1  Spain Primera Division          1.0       92         92   79000000
# 2    German 1. Bundesliga          1.0       90         90   54500000
# 3          French Ligue 1          1.0       90         90   52500000
# 4    German 1. Bundesliga          1.0       90         90   63500000
#
#    wage_eur player_positions preferred_foot  international_reputation  \
# 0    550000               CF           Left                         5
# 1    375000           LW, LM          Right                         5
# 2    275000       RM, LM, RW           Left                         5
# 3    275000               ST          Right                         5
# 4    300000               GK          Right                         5
#
#    weak_foot  skill_moves      work_rate body_type real_face  \
# 0          3            4     Medium/Low    Normal       Yes
# 1          4            5       High/Low    Normal       Yes
# 2          2            4       High/Low    Normal       Yes
# 3          4            4     Medium/Low    Normal       Yes
# 4          4            1  Medium/Medium    Normal       Yes
#
#    release_clause_eur                                        player_tags  \
# 0                 NaN  #Speedster, #Dribbler, #FK Specialist, #Acroba...
# 1                 NaN  #Speedster, #Dribbler, #Distance Shooter, #Acr...
# 2                 NaN  #Speedster, #Dribbler, #Distance Shooter, #Acr...
# 3                 NaN  #Poacher, #Aerial Threat, #Distance Shooter, #...
# 4                 NaN                                                NaN
#
#   team_position  team_jersey_number loaned_from      joined  \
# 0            CF                10.0         NaN  2004-07-01
# 1            LW                 7.0         NaN  2009-07-01
# 2           SUB                10.0         NaN  2009-08-28
# 3            ST                10.0         NaN  2012-07-01
# 4            GK                 1.0         NaN  2011-07-01
#
#    contract_valid_until nation_position  nation_jersey_number  pace  shooting  \
# 0                2018.0              CF                  10.0  93.0      89.0
# 1                2018.0              LW                   7.0  93.0      93.0
# 2                2017.0              RS                  11.0  93.0      86.0
# 3                2016.0              ST                  10.0  76.0      91.0
# 4                2019.0              GK                   1.0   NaN       NaN
#
#    passing  dribbling  defending  physic  gk_diving  gk_handling  gk_kicking  \
# 0     86.0       96.0       27.0    63.0        NaN          NaN         NaN
# 1     81.0       91.0       32.0    79.0        NaN          NaN         NaN
# 2     83.0       92.0       32.0    64.0        NaN          NaN         NaN
# 3     81.0       86.0       34.0    86.0        NaN          NaN         NaN
# 4      NaN        NaN        NaN     NaN       87.0         85.0        92.0
#
#    gk_reflexes  gk_speed  gk_positioning  \
# 0          NaN       NaN             NaN
# 1          NaN       NaN             NaN
# 2          NaN       NaN             NaN
# 3          NaN       NaN             NaN
# 4         86.0      60.0            90.0
#
#                                        player_traits  attacking_crossing  \
# 0  Finesse Shot, Speed Dribbler (AI), One Club Pl...                  84
# 1  Power Free-Kick, Flair, Long Shot Taker (AI), ...                  83
# 2  Diver, Injury Prone, Avoids Using Weaker Foot,...                  80
# 3  Power Free-Kick, Leadership, Flair, Long Shot ...                  76
# 4      GK Up for Corners, GK Long Throw, 1-on-1 Rush                  25
#
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   94                          71                       89
# 1                   95                          86                       82
# 2                   85                          50                       86
# 3                   91                          76                       84
# 4                   25                          25                       42
#
#    attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  \
# 0                 85               96           89                 90
# 1                 87               93           88                 79
# 2                 86               93           85                 83
# 3                 92               88           80                 80
# 4                 25               25           25                 25
#
#    skill_long_passing  skill_ball_control  movement_acceleration  \
# 0                  76                  96                     96
# 1                  72                  92                     91
# 2                  76                  90                     93
# 3                  76                  90                     74
# 4                  41                  31                     58
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                     90                94                  94
# 1                     94                93                  90
# 2                     93                93                  89
# 3                     77                86                  85
# 4                     61                43                  89
#
#    movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                95                80             73             77
# 1                63                94             94             89
# 2                91                86             61             78
# 3                41                93             72             78
# 4                35                42             78             44
#
#    power_strength  power_long_shots  mentality_aggression  \
# 0              60                88                    48
# 1              79                93                    63
# 2              65                90                    47
# 3              93                88                    84
# 4              83                25                    29
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       22                     92                90
# 1                       24                     91                81
# 2                       39                     89                84
# 3                       20                     86                83
# 4                       30                     25                20
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   76                  NaN                 25
# 1                   85                  NaN                 22
# 2                   80                  NaN                 29
# 3                   91                  NaN                 25
# 4                   37                  NaN                 25
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                         21                        20                   6
# 1                         31                        23                   7
# 2                         26                        26                  10
# 3                         41                        27                  13
# 4                         25                        25                  87
#
#    goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 0                    11                   15                       14
# 1                    11                   15                       14
# 2                     8                   11                        5
# 3                    15                   10                        9
# 4                    85                   92                       90
#
#    goalkeeping_reflexes    ls    st    rs    lw    lf    cf    rf    rw   lam  \
# 0                     8  89+3  89+3  89+3  92+3  90+3  90+3  90+3  92+3  92+3
# 1                    11  91+1  91+1  91+1  89+3  91+1  91+1  91+1  89+3  89+3
# 2                    15  84+3  84+3  84+3  88+2  87+3  87+3  87+3  88+2  88+2
# 3                    12  87+3  87+3  87+3  84+3  86+3  86+3  86+3  84+3  86+3
# 4                    86  38+3  38+3  38+3  36+3  37+3  37+3  37+3  36+3  36+3
#
#     cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm   cdm   rdm   rwb  \
# 0  92+3  92+3  90+3  79+3  79+3  79+3  90+3  62+3  62+3  62+3  62+3  62+3
# 1  89+3  89+3  87+3  77+3  77+3  77+3  87+3  63+3  63+3  63+3  63+3  63+3
# 2  88+2  88+2  87+3  78+3  78+3  78+3  87+3  64+3  64+3  64+3  64+3  64+3
# 3  86+3  86+3  83+3  76+3  76+3  76+3  83+3  61+3  65+3  65+3  65+3  61+3
# 4  36+3  36+3  38+3  36+3  36+3  36+3  38+3  36+3  40+3  40+3  40+3  36+3
#
#      lb   lcb    cb   rcb    rb
# 0  54+3  45+3  45+3  45+3  54+3
# 1  57+3  52+3  52+3  52+3  57+3
# 2  55+3  46+3  46+3  46+3  55+3
# 3  56+3  55+3  55+3  55+3  56+3
# 4  36+3  38+3  38+3  38+3  36+3

# %%
# fif15_j.drop(columns= ['sofifa_id', 'player_url', 'age', 'height_cm', 
#                               'weight_kg', 'league_name', 'league_rank', 'potential', 
#                               'value_eur', 'wage_eur', 'preferred_foot', 'international_reputation', 'weak_foot', 'skill_moves',
#                              'work_rate', 'real_face', 'release_clause_eur', 'player_tags', 'team_jersey_number',
#                              'loaned_from', 'joined', 'contract_valid_until', 'nation_position', 'nation_jersey_number',
#                              'player_traits', 'mentality_composure', 'ls', 'st', 'rs', 'lw', 'lf', 'cf',
#                              'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm'], inplace=True)
fif19_j.head()

fif19_j.to_pickle("./players.pkl")
# Out:
#    sofifa_id                                         player_url  \
# 0      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1     158023  https://sofifa.com/player/158023/lionel-messi/...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     193080  https://sofifa.com/player/193080/david-de-gea-...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name  age         dob  \
# 0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   33  1985-02-05
# 1           L. Messi       Lionel Andrés Messi Cuccittini   31  1987-06-24
# 2             Neymar        Neymar da Silva Santos Júnior   26  1992-02-05
# 3             De Gea                David De Gea Quintana   27  1990-11-07
# 4       K. De Bruyne                      Kevin De Bruyne   27  1991-06-28
#
#    height_cm  weight_kg nationality            club_name  \
# 0        187         83    Portugal             Juventus
# 1        170         72   Argentina         FC Barcelona
# 2        175         68      Brazil  Paris Saint-Germain
# 3        193         76       Spain    Manchester United
# 4        181         70     Belgium      Manchester City
#
#               league_name  league_rank  overall  potential  value_eur  \
# 0         Italian Serie A          1.0       94         94   77000000
# 1  Spain Primera Division          1.0       94         94  110500000
# 2          French Ligue 1          1.0       92         93  118500000
# 3  English Premier League          1.0       91         93   72000000
# 4  English Premier League          1.0       91         92  102000000
#
#    wage_eur player_positions preferred_foot  international_reputation  \
# 0    400000           ST, LW          Right                         5
# 1    575000       CF, RW, ST           Left                         5
# 2    300000               LW          Right                         5
# 3    250000               GK          Right                         4
# 4    350000          CAM, CM          Right                         4
#
#    weak_foot  skill_moves      work_rate   body_type real_face  \
# 0          4            5       High/Low  C. Ronaldo       Yes
# 1          4            4  Medium/Medium       Messi       Yes
# 2          5            5    High/Medium      Neymar       Yes
# 3          3            1  Medium/Medium        Lean       Yes
# 4          5            4      High/High      Normal       Yes
#
#    release_clause_eur                                        player_tags  \
# 0         127100000.0  #Speedster, #Dribbler, #Distance Shooter, #Acr...
# 1         226500000.0  #Dribbler, #Distance Shooter, #FK Specialist, ...
# 2         228100000.0  #Speedster, #Dribbler, #FK Specialist, #Acroba...
# 3         138600000.0                                                NaN
# 4         196400000.0  #Dribbler, #Playmaker, #Engine, #Distance Shoo...
#
#   team_position  team_jersey_number loaned_from      joined  \
# 0            ST                 7.0         NaN  2018-07-10
# 1            RW                10.0         NaN  2004-07-01
# 2            LW                10.0         NaN  2017-08-03
# 3            GK                 1.0         NaN  2011-07-01
# 4           RCM                17.0         NaN  2015-08-30
#
#    contract_valid_until nation_position  nation_jersey_number  pace  shooting  \
# 0                2022.0              LS                   7.0  90.0      93.0
# 1                2021.0              CF                  10.0  88.0      91.0
# 2                2022.0              LW                  10.0  92.0      84.0
# 3                2019.0              GK                   1.0   NaN       NaN
# 4                2023.0             RCM                   7.0  77.0      86.0
#
#    passing  dribbling  defending  physic  gk_diving  gk_handling  gk_kicking  \
# 0     81.0       89.0       35.0    79.0        NaN          NaN         NaN
# 1     88.0       96.0       32.0    61.0        NaN          NaN         NaN
# 2     83.0       95.0       32.0    59.0        NaN          NaN         NaN
# 3      NaN        NaN        NaN     NaN       90.0         85.0        87.0
# 4     92.0       87.0       60.0    78.0        NaN          NaN         NaN
#
#    gk_reflexes  gk_speed  gk_positioning  \
# 0          NaN       NaN             NaN
# 1          NaN       NaN             NaN
# 2          NaN       NaN             NaN
# 3         94.0      58.0            88.0
# 4          NaN       NaN             NaN
#
#                                        player_traits  attacking_crossing  \
# 0  Power Free-Kick, Diver, Flair, Long Shot Taker...                  84
# 1  Finesse Shot, Long Shot Taker (AI), Speed Drib...                  77
# 2  Diver, Selfish, Flair, Speed Dribbler (AI), Te...                  79
# 3                     GK Long Throw, Saves with Feet                  17
# 4  Leadership, Early Crosser, Long Passer (AI), L...                  93
#
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   94                          89                       81
# 1                   95                          70                       90
# 2                   87                          62                       84
# 3                   13                          21                       50
# 4                   83                          55                       92
#
#    attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  \
# 0                 87               88           81                 76
# 1                 86               97           93                 94
# 2                 84               96           88                 87
# 3                 13               18           21                 19
# 4                 82               86           85                 83
#
#    skill_long_passing  skill_ball_control  movement_acceleration  \
# 0                  77                  94                     89
# 1                  87                  96                     91
# 2                  78                  95                     94
# 3                  51                  42                     57
# 4                  91                  91                     78
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                     91                87                  96
# 1                     86                91                  95
# 2                     90                96                  94
# 3                     58                60                  90
# 4                     76                79                  91
#
#    movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                70                95             95             88
# 1                95                85             68             72
# 2                84                80             61             81
# 3                43                31             67             43
# 4                77                91             63             90
#
#    power_strength  power_long_shots  mentality_aggression  \
# 0              79                93                    63
# 1              59                94                    48
# 2              49                82                    56
# 3              64                12                    38
# 4              75                91                    76
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       29                     95                82
# 1                       22                     94                94
# 2                       36                     89                87
# 3                       30                     12                68
# 4                       60                     87                94
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   85                   95                 28
# 1                   75                   96                 33
# 2                   81                   94                 27
# 3                   40                   68                 15
# 4                   79                   88                 67
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                         31                        23                   7
# 1                         28                        26                   6
# 2                         24                        33                   9
# 3                         21                        13                  90
# 4                         58                        51                  15
#
#    goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 0                    11                   15                       14
# 1                    11                   15                       14
# 2                     9                   15                       15
# 3                    85                   87                       88
# 4                    13                    5                       10
#
#    goalkeeping_reflexes    ls    st    rs    lw    lf    cf    rf    rw   lam  \
# 0                    11  92+2  92+2  92+2  90+0  91+0  91+0  91+0  90+0  88+4
# 1                     8  89+5  89+5  89+5  92+2  93+1  93+1  93+1  92+2  93+1
# 2                    11  84+7  84+7  84+7  90+3  90+3  90+3  90+3  90+3  90+3
# 3                    94  33+2  33+2  33+2   37+   38+   38+   38+   37+  43+2
# 4                    13  83+3  83+3  83+3  87+0  87+0  87+0  87+0  87+0  89+3
#
#     cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm   cdm   rdm   rwb  \
# 0  88+4  88+4  88+4  81+4  81+4  81+4  88+4  65+4  61+4  61+4  61+4  65+4
# 1  93+1  93+1  91+3  85+7  85+7  85+7  91+3  63+7  61+7  61+7  61+7  63+7
# 2  90+3  90+3  89+4  81+7  81+7  81+7  89+4  66+7  61+7  61+7  61+7  66+7
# 3  43+2  43+2  40+2  45+2  45+2  45+2  40+2  36+2  41+2  41+2  41+2  36+2
# 4  89+3  89+3  88+3  88+3  88+3  88+3  88+3  77+3  77+3  77+3  77+3  77+3
#
#      lb   lcb    cb   rcb    rb
# 0  61+4  54+4  54+4  54+4  61+4
# 1  59+7  48+7  48+7  48+7  59+7
# 2  61+7  47+7  47+7  47+7  61+7
# 3  35+2  34+2  34+2  34+2  35+2
# 4  73+3  67+3  67+3  67+3  73+3

# %%
fifa_dataset_list = [fif15_j, fif16_j, fif17_j, fif18_j, fif19_j, fif20_j, fif21_j]
import pickle
with open('players.pkl', 'wb') as f:
    pickle.dump(fifa_dataset_list, f)

# %%
fifa_dataset_list = [fif15_j, fif16_j, fif17_j, fif18_j, fif19_j, fif20_j, fif21_j]
def joining_func(fifa_dataset_list):
    new_list = []
    for season in fifa_dataset_list:
        new_season = season.drop(columns= ['sofifa_id', 'player_url', 'age', 'height_cm', 'dob', 'body_type', 'player_positions', 
                              'weight_kg', 'league_rank', 'potential', 
                              'value_eur', 'wage_eur', 'preferred_foot', 'international_reputation', 'weak_foot', 'skill_moves',
                             'work_rate', 'real_face', 'release_clause_eur', 'player_tags', 'team_jersey_number',
                             'loaned_from', 'joined', 'contract_valid_until', 'nation_position', 'nation_jersey_number',
                             'player_traits', 'mentality_composure', 'ls', 'st', 'rs', 'lw', 'lf', 'cf',
                             'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm',
                             'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'], inplace=True)
        new_season = season[(season['league_name'] == 'Spain Primera Division') | (season['league_name'] == 'German 1. Bundesliga') | (season['league_name'] == 'French Ligue 1') | (season['league_name'] == 'Italian Serie A') | (season['league_name'] == 'English Premier League')] 
        new_list.append(new_season)
    return new_list

# %%
# new = joining_func(fifa_dataset_list)
# new[6][(new[6]['league_name'] == 'French Ligue 1')]['club_name'].unique()
new[0]['Season'] = '2014/2015'
new[1]['Season'] = '2015/2016'
new[2]['Season'] = '2016/2017'
new[3]['Season'] = '2017/2018'
new[4]['Season'] = '2018/2019'
new[5]['Season'] = '2019/2020'
new[6]['Season'] = '2020/2021'
with open('players.pkl', 'wb') as f:
    pickle.dump(new, f)
# Out:
# <ipython-input-74-0750c95f1f37>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new[0]['Season'] = '2014/2015'
# <ipython-input-74-0750c95f1f37>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new[1]['Season'] = '2015/2016'
# <ipython-input-74-0750c95f1f37>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new[2]['Season'] = '2016/2017'
# <ipython-input-74-0750c95f1f37>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new[3]['Season'] = '2017/2018'
# <ipython-input-74-0750c95f1f37>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new[4]['Season'] = '2018/2019'
# <ipython-input-74-0750c95f1f37>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new[5]['Season'] = '2019/2020'
# <ipython-input-74-0750c95f1f37>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new[6]['Season'] = '2020/2021'

# %%
games_nonull[(games_nonull['League'] == 'Le Championnat')]['HomeTeam'].unique()
# Out:
# array(['Marseille', 'Nantes', 'Montpellier', 'St Etienne', 'Nice',
#        'Nimes', 'Brest', 'Lens', 'Lyon', 'Lorient', 'Paris SG', 'Monaco',
#        'Dijon', 'Rennes', 'Strasbourg', 'Reims', 'Metz', 'Bordeaux',
#        'Lille', 'Angers', 'Toulouse', 'Amiens', 'Caen', 'Guingamp',
#        'Troyes', 'Nancy', 'Bastia', 'Ajaccio GFCO',
#        'Evian Thonon Gaillard'], dtype=object)

# %%
# games_nonull[(games_nonull['League'] == 'Serie A')]['HomeTeam'].unique()
'Olympique de Marseille', 'FC Nantes', 'Montpellier HSC', 'AS Saint-Étienne', 'OGC Nice', 'Nîmes Olympique',
'Stade Brestois 29','Racing Club de Lens', 'Olympique Lyonnais', 'FC Lorient', 'Paris Saint-Germain', 'AS Monaco', 'Dijon FCO',
'Stade Rennais FC', 'RC Strasbourg Alsace', 'Stade de Reims', 'FC Metz','FC Girondins de Bordeaux', 'LOSC Lille',
'Angers SCO', 'Toulouse Football Club', 'Amiens SC', 'Stade Malherbe Caen','En Avant de Guingamp', 'ESTAC Troyes',
'AS Nancy Lorraine', 'Sporting Club de Bastia', 'GFC Ajaccio', 'Évian Thonon Gaillard FC'

# %%
#Spain(zaragoza, santander, 'Hercules', 'Xerez', 'Tenerife','Numancia', 'Recreativo', 'Murcia', 'Gimnastic', 'Albacete')
#English(hamilton, ross county, st mirren, hibernian, livingsont, celtic, motherwell, kilmarnock, aberdeen, hearts, dundee united
#st johnstone, 'Hearts', 'Dundee', 'Huddersfield', 'Cardiff', patrick, 'Inverness C', 'Middlesbrough', 'QPR', 'Wigan', 
# 'Reading', 'Dunfermline',
#        'Blackburn', 'Bolton', 'Birmingham', 'Blackpool', 'Falkirk',
#        'Portsmouth', 'Gretna', 'Derby', 'Charlton')
#Italy NONE! YAAAAA
#German(bielefeld, nurnberg )
#Frenchies('Sochaux', 'Valenciennes', 'Ajaccio','Auxerre', 'Arles', 'Boulogne', 'Grenoble', 'Le Mans', 'Le Havre','Sedan', 'Istres')
original =['Ath Madrid', 'Betis', 'Osasuna', 'Ath Bilbao', 'Sociedad',
       'Sevilla', 'Elche', 'Huesca', 'Levante', 'Alaves', 'Barcelona',
       'Granada', 'Cadiz', 'Getafe', 'Villarreal', 'Valencia',
       'Real Madrid', 'Eibar', 'Valladolid', 'Celta', 'Espanol',
       'Leganes', 'Mallorca', 'Girona', 'Vallecano', 'Malaga',
       'Las Palmas', 'La Coruna', 'Sp Gijon', 'Almeria', 'Cordoba', 
           'Leeds', 'Sheffield United', 'Liverpool', 'Wolves', 'Tottenham','Man United','Fulham','Newcastle','Burnley',  
'Aston Villa', 'Rangers', 'Brighton', 'West Ham', 'Leicester', 'Chelsea', 'Southampton','Arsenal', 'West Brom', 
'Crystal Palace','Man City', 'Everton', 'Watford', 'Bournemouth','Norwich',  'Swansea', 'Stoke', 'Hull', 'Sunderland',
          'Hoffenheim', "M'gladbach", 'Freiburg', 'Leverkusen', 'Mainz',
       'Schalke 04', 'Augsburg', 'Hertha', 'Wolfsburg', 'FC Koln',
       'RB Leipzig', 'Union Berlin', 'Dortmund', 'Bayern Munich',
       'Werder Bremen', 'Ein Frankfurt', 'Stuttgart',
       'Fortuna Dusseldorf', 'Paderborn', 'Hannover',
       'Hamburg', 'Marseille', 'Nantes', 'Montpellier', 'St Etienne', 'Nice',
       'Nimes', 'Brest', 'Lens', 'Lyon', 'Lorient', 'Paris SG', 'Monaco',
       'Dijon', 'Rennes', 'Strasbourg', 'Reims', 'Metz', 'Bordeaux',
       'Lille', 'Angers', 'Toulouse', 'Amiens', 'Caen', 'Guingamp',
       'Troyes', 'Nancy', 'Bastia', 'Ajaccio GFCO',
       'Evian Thonon Gaillard']
replacements=['Atlético Madrid', 'Real Betis', 'CA Osasuna', 'Athletic Club de Bilbao','Real Sociedad', 'Sevilla FC', 'Elche CF', 'SD Huesca',
            'Levante UD', 'Deportivo Alavés', 'FC Barcelona', 'Granada CF', 'Cádiz CF', 'Getafe CF', 
             'Villarreal CF', 'Valencia CF', 'Real Madrid', 'SD Eibar', 'Real Valladolid CF', 'RC Celta',
            'RCD Espanyol', 'CD Leganés', 'RCD Mallorca', 'Girona FC', 'Rayo Vallecano', 'Málaga CF',
            'UD Las Palmas', 'Deportivo de La Coruña', 'Real Sporting de Gijón', 'UD Almería', 'Córdoba CF', 
             'Leeds United', 'Sheffield United', 'Liverpool', 'Wolverhampton Wanderers', 'Tottenham Hotspur', 
             'Manchester United','Fulham', 'Newcastle United', 'Burnley', 'Aston Villa', 'Queens Park Rangers', 
             'Brighton & Hove Albion','West Ham United', 'Leicester City', 'Chelsea', 'Southampton', 'Arsenal', 
             'West Bromwich Albion', 'Crystal Palace','Manchester City', 'Everton', 'Watford', 'Bournemouth', 
             'Norwich City', 'Swansea City', 'Stoke City', 'Hull City','Sunderland', 'TSG 1899 Hoffenheim', 'Borussia Mönchengladbach', 'SC Freiburg', 'Bayer 04 Leverkusen', '1. FSV Mainz 05', 
'FC Schalke 04', 'FC Augsburg', 'Hertha BSC','VfL Wolfsburg', '1. FC Köln', 'RB Leipzig', '1. FC Union Berlin',
'Borussia Dortmund', 'FC Bayern München', 'SV Werder Bremen','Eintracht Frankfurt', 'VfB Stuttgart', 
'Fortuna Düsseldorf', 'SC Paderborn 07','Hannover 96', 'Hamburger SV', 'Olympique de Marseille', 'FC Nantes', 'Montpellier HSC', 'AS Saint-Étienne', 'OGC Nice', 'Nîmes Olympique',
'Stade Brestois 29','Racing Club de Lens', 'Olympique Lyonnais', 'FC Lorient', 'Paris Saint-Germain', 'AS Monaco', 'Dijon FCO',
'Stade Rennais FC', 'RC Strasbourg Alsace', 'Stade de Reims', 'FC Metz','FC Girondins de Bordeaux', 'LOSC Lille',
'Angers SCO', 'Toulouse Football Club', 'Amiens SC', 'Stade Malherbe Caen','En Avant de Guingamp', 'ESTAC Troyes',
'AS Nancy Lorraine', 'Sporting Club de Bastia', 'GFC Ajaccio', 'Évian Thonon Gaillard FC']
len(replacements)
# len(original)
# Out:
# 109

# %%
games_15_21 = games_nonull.copy()
def replacement(original, replacer):
    for i, team_og in enumerate(original):
        
        games_15_21.replace(to_replace=original[i], value=replacer[i],inplace=True)
    return games_15_21

# %%
replacement(original, replacements)
games_15_21
games_15_21.to_pickle("./all_games.pkl")

# %%
def joiner(fifa_dataset_list):
    new_list = []
    for season in fifa_dataset_list:
        new_season = season.drop(columns= ['sofifa_id', 'player_url', 'age', 'height_cm', 'dob', 'body_type', 'player_positions', 
                              'weight_kg', 'league_rank', 'potential', 
                              'value_eur', 'wage_eur', 'preferred_foot', 'international_reputation', 'weak_foot', 'skill_moves',
                             'work_rate', 'real_face', 'release_clause_eur', 'player_tags', 'team_jersey_number',
                             'loaned_from', 'joined', 'contract_valid_until', 'nation_position', 'nation_jersey_number',
                             'player_traits', 'mentality_composure', 'ls', 'st', 'rs', 'lw', 'lf', 'cf',
                             'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm',
                             'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'], inplace=True)
        new_season = season[(season['league_name'] == 'Spain Primera Division') | (season['league_name'] == 'German 1. Bundesliga') | (season['league_name'] == 'French Ligue 1') | (season['league_name'] == 'Italian Serie A') | (season['league_name'] == 'English Premier League')] 
        new_list.append(new_season)
    return new_list

# %%
with open('players.pkl', 'wb') as f:
    pickle.dump(new, f)
new[0].head(2)
# Out:
#           short_name                            long_name nationality  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   Argentina
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro    Portugal
#
#       club_name             league_name  overall team_position  pace  \
# 0  FC Barcelona  Spain Primera Division       93            CF  93.0
# 1   Real Madrid  Spain Primera Division       92            LW  93.0
#
#    shooting  passing  dribbling  defending  physic  gk_diving  gk_handling  \
# 0      89.0     86.0       96.0       27.0    63.0        NaN          NaN
# 1      93.0     81.0       91.0       32.0    79.0        NaN          NaN
#
#    gk_kicking  gk_reflexes  gk_speed  gk_positioning  attacking_crossing  \
# 0         NaN          NaN       NaN             NaN                  84
# 1         NaN          NaN       NaN             NaN                  83
#
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   94                          71                       89
# 1                   95                          86                       82
#
#    attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  \
# 0                 85               96           89                 90
# 1                 87               93           88                 79
#
#    skill_long_passing  skill_ball_control  movement_acceleration  \
# 0                  76                  96                     96
# 1                  72                  92                     91
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                     90                94                  94
# 1                     94                93                  90
#
#    movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                95                80             73             77
# 1                63                94             94             89
#
#    power_strength  power_long_shots  mentality_aggression  \
# 0              60                88                    48
# 1              79                93                    63
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       22                     92                90
# 1                       24                     91                81
#
#    mentality_penalties  defending_marking  defending_standing_tackle  \
# 0                   76                 25                         21
# 1                   85                 22                         31
#
#    defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# 0                        20                   6                    11
# 1                        23                   7                    11
#
#    goalkeeping_kicking  goalkeeping_positioning  goalkeeping_reflexes  \
# 0                   15                       14                     8
# 1                   15                       14                    11
#
#       Season
# 0  2014/2015
# 1  2014/2015

# %%
#want to join on season and club
new[0]['team_position'].unique()
# center forward, 
# new.to_pickle("./players.pkl")
# Out:
# array(['CF', 'LW', 'ST', 'GK', 'RES', 'LCM', 'LM', 'RS', 'RW', 'LS',
#        'RCM', 'LCB', 'CAM', 'LDM', 'RCB', 'CM', 'CDM', 'CB', 'RDM', 'RB',
#        'RM', 'LB', 'RAM', 'LAM', 'RWB', 'LWB'], dtype=object)

# %% [markdown]
# ## New Columns for Analysis

# %% [markdown]
# - Defense ?(defending, defending_marking, defending_standing_tackle, defending_sliding_tackle)?
# - Offense (passing, dribbling, attacking_crossing, attacking_finishing, attacking_heading_accuracy, skill_long_passing, skill_ball_control)
# - Agility/Fitness (pace, movement_acceleration, movement_sprint_speed, movement_agility, movement_reactions, movement_balance, power_jumping, power_stamina, power_strength)
# - Goalkeeping -only GKs (gk_diving, gk_handling, gk_kicking, gk_reflexes, gk_speed, gk_positioning, goalkeeping_diving, goalkeeping_handling, goalkeeping_kicking, goalkeeping_positioning, goalkeeping_reflexes)
# - Scoring (shooting,attacking_crossing, attacking_finishing, attacking_heading_accuracy, skill_fk_accuracy, power_shot_power, power_long_shots)
# - Mentality (mentality_aggression, mentality_interceptions, mentality_positioning, mentality_vision, mentality_penalties)
# - Avg Nationality (most common nationality on team)

# %%
def defense_column(fifas):
    years = ['2014/2015', "2015/2016", "2016/2017", "2017/2018", "2018/2019", "2019/2020", "2020/2021"]
    updated_fifas = []
    for i, season in enumerate(fifas):
        subs = season[(season['team_position'] == 'SUB')].index
        season.drop(subs, inplace=True)
        defending = season.groupby('club_name').agg({'defending': ['mean']})
        defending['overall'] = season.groupby('club_name').agg({'overall': ['mean']})
        
        defending['Season'] = years[i]
        updated_fifas.append(defending)
    return updated_fifas

# %%
fifa_ags = defense_column(new)

fifa_ags_def = fifa_ags[0].append(fifa_ags[1])
fifa_ags_def = fifa_ags_def.append(fifa_ags[2])
fifa_ags_def = fifa_ags_def.append(fifa_ags[3])
fifa_ags_def = fifa_ags_def.append(fifa_ags[4])
fifa_ags_def = fifa_ags_def.append(fifa_ags[5])
fifa_ags_def = fifa_ags_def.append(fifa_ags[6])
fifa_ags_def.columns = ['defending_mean', 'overall', 'Season']
fifa_ags_def.index.name = 'club_name'
fifa_ags_def.reset_index(inplace=True)
fifa_ags_def
# Out:
# /Users/SirLawrenceKatz/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                    club_name  defending_mean    overall     Season
# 0                 1. FC Köln       52.214286  68.812500  2014/2015
# 1            1. FSV Mainz 05       52.277778  68.000000  2014/2015
# 2                  AS Monaco       57.384615  72.562500  2014/2015
# 3           AS Saint-Étienne       57.400000  69.941176  2014/2015
# 4                    Arsenal       56.058824  71.571429  2014/2015
# ..                       ...             ...        ...        ...
# 681            VfL Wolfsburg       53.600000  71.000000  2020/2021
# 682            Villarreal CF       59.555556  73.000000  2020/2021
# 683     West Bromwich Albion       52.277778  67.650000  2020/2021
# 684          West Ham United       55.944444  69.380952  2020/2021
# 685  Wolverhampton Wanderers       55.550000  70.238095  2020/2021
#
# [686 rows x 4 columns]

# %%
fifa_ags_def['defense_mean'] = fifa_ags_def.mean(axis=1)
fifa_ags_def
# Out:
#                    club_name  defending_mean    overall     Season  \
# 0                 1. FC Köln       52.214286  68.812500  2014/2015
# 1            1. FSV Mainz 05       52.277778  68.000000  2014/2015
# 2                  AS Monaco       57.384615  72.562500  2014/2015
# 3           AS Saint-Étienne       57.400000  69.941176  2014/2015
# 4                    Arsenal       56.058824  71.571429  2014/2015
# ..                       ...             ...        ...        ...
# 681            VfL Wolfsburg       53.600000  71.000000  2020/2021
# 682            Villarreal CF       59.555556  73.000000  2020/2021
# 683     West Bromwich Albion       52.277778  67.650000  2020/2021
# 684          West Ham United       55.944444  69.380952  2020/2021
# 685  Wolverhampton Wanderers       55.550000  70.238095  2020/2021
#
#      defense_mean
# 0       60.513393
# 1       60.138889
# 2       64.973558
# 3       63.670588
# 4       63.815126
# ..            ...
# 681     62.300000
# 682     66.277778
# 683     59.963889
# 684     62.662698
# 685     62.894048
#
# [686 rows x 5 columns]

# %%
def offense_column(fifas):
    years = ['2014/2015', "2015/2016", "2016/2017", "2017/2018", "2018/2019", "2019/2020", "2020/2021"]
    offense_columns = ['passing', 'dribbling', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 
                       'skill_long_passing', 'skill_ball_control']
    updated_fifas = []
    for i, season in enumerate(fifas):
        
        subs = season[(season['team_position'] == 'SUB')].index
        season.drop(subs, inplace=True)
        offense = season.groupby('club_name').agg({'passing': ['mean']})
#         offense.iloc[:,1] = ['passing mean']
        offense['dribbling mean'] = season.groupby('club_name').agg({'dribbling': ['mean']})
        offense['attacking_crossing mean'] = season.groupby('club_name').agg({'attacking_crossing': ['mean']})
        offense['attacking_finishing mean'] = season.groupby('club_name').agg({'attacking_finishing': ['mean']})
        offense['attacking_heading_accuracy mean'] = season.groupby('club_name').agg({'attacking_heading_accuracy': ['mean']})
        offense['skill_long_passing'] = season.groupby('club_name').agg({'skill_long_passing': ['mean']})
        offense['skill_ball_control'] = season.groupby('club_name').agg({'skill_ball_control': ['mean']})
      

        offense['Season'] = years[i]

            
        
        updated_fifas.append(offense)
    return updated_fifas

# %%
fifa_ags = offense_column(new)
fifa_ags[0]
fifa_ags_off = fifa_ags[0].append(fifa_ags[1])
fifa_ags_off = fifa_ags_off.append(fifa_ags[2])
fifa_ags_off = fifa_ags_off.append(fifa_ags[3])
fifa_ags_off = fifa_ags_off.append(fifa_ags[4])
fifa_ags_off = fifa_ags_off.append(fifa_ags[5])
fifa_ags_off = fifa_ags_off.append(fifa_ags[6])
# fifa_ags_off.columns = ['defending_mean', 'season']
fifa_ags_off.index.name = 'club_name'
fifa_ags_off.reset_index(inplace=True)
fifa_ags_off
# Out:
# /Users/SirLawrenceKatz/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                    club_name    passing dribbling mean  \
#                                    mean
# 0                 1. FC Köln  56.928571      64.285714
# 1            1. FSV Mainz 05  62.333333      67.833333
# 2                  AS Monaco  67.769231      69.538462
# 3           AS Saint-Étienne  61.600000      65.000000
# 4                    Arsenal  65.647059      71.235294
# ..                       ...        ...            ...
# 681            VfL Wolfsburg  61.266667      68.466667
# 682            Villarreal CF  63.444444      68.166667
# 683     West Bromwich Albion  57.222222      62.888889
# 684          West Ham United  60.722222      66.111111
# 685  Wolverhampton Wanderers  62.900000      67.350000
#
#     attacking_crossing mean attacking_finishing mean  \
#
# 0                 50.750000                48.875000
# 1                 57.950000                50.250000
# 2                 57.437500                50.812500
# 3                 56.352941                49.705882
# 4                 54.952381                49.047619
# ..                      ...                      ...
# 681               49.722222                50.333333
# 682               53.550000                51.650000
# 683               49.400000                44.250000
# 684               51.285714                45.428571
# 685               57.523810                50.619048
#
#     attacking_heading_accuracy mean skill_long_passing skill_ball_control  \
#
# 0                         58.562500          50.625000          60.437500
# 1                         57.300000          57.500000          63.550000
# 2                         60.000000          58.562500          64.250000
# 3                         60.588235          55.882353          60.941176
# 4                         55.095238          56.857143          62.952381
# ..                              ...                ...                ...
# 681                       52.722222          51.777778          61.833333
# 682                       58.550000          59.000000          65.750000
# 683                       53.500000          54.700000          59.000000
# 684                       52.238095          55.000000          60.809524
# 685                       54.666667          61.238095          66.333333
#
#         Season
#
# 0    2014/2015
# 1    2014/2015
# 2    2014/2015
# 3    2014/2015
# 4    2014/2015
# ..         ...
# 681  2020/2021
# 682  2020/2021
# 683  2020/2021
# 684  2020/2021
# 685  2020/2021
#
# [686 rows x 9 columns]

# %%
fifa_ags_off['offense_mean'] = fifa_ags_off.mean(axis=1)
fifa_ags_off
# Out:
#                    club_name    passing dribbling mean  \
#                                    mean
# 0                 1. FC Köln  56.928571      64.285714
# 1            1. FSV Mainz 05  62.333333      67.833333
# 2                  AS Monaco  67.769231      69.538462
# 3           AS Saint-Étienne  61.600000      65.000000
# 4                    Arsenal  65.647059      71.235294
# ..                       ...        ...            ...
# 681            VfL Wolfsburg  61.266667      68.466667
# 682            Villarreal CF  63.444444      68.166667
# 683     West Bromwich Albion  57.222222      62.888889
# 684          West Ham United  60.722222      66.111111
# 685  Wolverhampton Wanderers  62.900000      67.350000
#
#     attacking_crossing mean attacking_finishing mean  \
#
# 0                 50.750000                48.875000
# 1                 57.950000                50.250000
# 2                 57.437500                50.812500
# 3                 56.352941                49.705882
# 4                 54.952381                49.047619
# ..                      ...                      ...
# 681               49.722222                50.333333
# 682               53.550000                51.650000
# 683               49.400000                44.250000
# 684               51.285714                45.428571
# 685               57.523810                50.619048
#
#     attacking_heading_accuracy mean skill_long_passing skill_ball_control  \
#
# 0                         58.562500          50.625000          60.437500
# 1                         57.300000          57.500000          63.550000
# 2                         60.000000          58.562500          64.250000
# 3                         60.588235          55.882353          60.941176
# 4                         55.095238          56.857143          62.952381
# ..                              ...                ...                ...
# 681                       52.722222          51.777778          61.833333
# 682                       58.550000          59.000000          65.750000
# 683                       53.500000          54.700000          59.000000
# 684                       52.238095          55.000000          60.809524
# 685                       54.666667          61.238095          66.333333
#
#         Season offense_mean
#
# 0    2014/2015    55.780612
# 1    2014/2015    59.530952
# 2    2014/2015    61.195742
# 3    2014/2015    58.581513
# 4    2014/2015    59.398159
# ..         ...          ...
# 681  2020/2021    56.588889
# 682  2020/2021    60.015873
# 683  2020/2021    54.423016
# 684  2020/2021    55.942177
# 685  2020/2021    60.090136
#
# [686 rows x 10 columns]

# %%
# Agility/Fitness (pace, movement_acceleration, movement_sprint_speed, movement_agility, movement_reactions, 
#                  movement_balance, power_jumping, power_stamina, power_strength)

def agility_fitness_column(fifas):
    years = ['2014/2015', "2015/2016", "2016/2017", "2017/2018", "2018/2019", "2019/2020", "2020/2021"]
    
    updated_fifas = []
    for i, season in enumerate(fifas):
        
        subs = season[(season['team_position'] == 'SUB')].index
        season.drop(subs, inplace=True)
        ag_fit = season.groupby('club_name').agg({'pace': ['mean']})

        ag_fit['movement_acceleration mean'] = season.groupby('club_name').agg({'movement_acceleration': ['mean']})
        ag_fit['movement_sprint_speed mean'] = season.groupby('club_name').agg({'movement_sprint_speed': ['mean']})
        ag_fit['movement_agility mean'] = season.groupby('club_name').agg({'movement_agility': ['mean']})
        ag_fit['movement_reactions mean'] = season.groupby('club_name').agg({'movement_reactions': ['mean']})
        ag_fit['movement_balance mean'] = season.groupby('club_name').agg({'movement_balance': ['mean']})
        ag_fit['power_jumping mean'] = season.groupby('club_name').agg({'power_jumping': ['mean']})
        ag_fit['power_stamina mean'] = season.groupby('club_name').agg({'power_stamina': ['mean']})
        ag_fit['power_strength mean'] = season.groupby('club_name').agg({'power_strength': ['mean']})

        ag_fit['Season'] = years[i]

            
        
        updated_fifas.append(ag_fit)
    return updated_fifas

# %%
fifa_ags = agility_fitness_column(new)

fifa_ags_ag_fit = fifa_ags[0].append(fifa_ags[1])
fifa_ags_ag_fit = fifa_ags_ag_fit.append(fifa_ags[2])
fifa_ags_ag_fit = fifa_ags_ag_fit.append(fifa_ags[3])
fifa_ags_ag_fit = fifa_ags_ag_fit.append(fifa_ags[4])
fifa_ags_ag_fit = fifa_ags_ag_fit.append(fifa_ags[5])
fifa_ags_ag_fit = fifa_ags_ag_fit.append(fifa_ags[6])
# fifa_ags_off.columns = ['defending_mean', 'season']
fifa_ags_ag_fit.index.name = 'club_name'
fifa_ags_ag_fit.reset_index(inplace=True)
fifa_ags_ag_fit
# Out:
# /Users/SirLawrenceKatz/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                    club_name       pace movement_acceleration mean  \
#                                    mean
# 0                 1. FC Köln  71.000000                  68.125000
# 1            1. FSV Mainz 05  74.333333                  71.850000
# 2                  AS Monaco  69.000000                  65.562500
# 3           AS Saint-Étienne  70.400000                  67.235294
# 4                    Arsenal  74.294118                  69.428571
# ..                       ...        ...                        ...
# 681            VfL Wolfsburg  70.866667                  66.000000
# 682            Villarreal CF  65.055556                  63.750000
# 683     West Bromwich Albion  68.666667                  67.000000
# 684          West Ham United  68.388889                  65.285714
# 685  Wolverhampton Wanderers  68.950000                  68.000000
#
#     movement_sprint_speed mean movement_agility mean movement_reactions mean  \
#
# 0                    68.562500             66.312500               66.812500
# 1                    73.000000             68.650000               67.250000
# 2                    65.500000             63.937500               69.625000
# 3                    67.705882             62.647059               66.764706
# 4                    68.428571             67.142857               68.809524
# ..                         ...                   ...                     ...
# 681                  65.277778             63.111111               69.888889
# 682                  62.600000             65.100000               68.950000
# 683                  65.400000             62.700000               64.100000
# 684                  63.809524             64.285714               65.809524
# 685                  68.666667             68.761905               66.619048
#
#     movement_balance mean power_jumping mean power_stamina mean  \
#
# 0               63.062500          69.250000          64.875000
# 1               66.700000          67.850000          64.850000
# 2               62.625000          68.187500          63.625000
# 3               62.705882          67.352941          68.588235
# 4               66.190476          61.476190          64.571429
# ..                    ...                ...                ...
# 681             62.444444          67.388889          64.055556
# 682             63.950000          66.600000          63.250000
# 683             64.000000          63.050000          64.000000
# 684             64.619048          65.047619          61.714286
# 685             68.285714          69.285714          68.095238
#
#     power_strength mean     Season
#
# 0             69.250000  2014/2015
# 1             65.850000  2014/2015
# 2             71.500000  2014/2015
# 3             70.470588  2014/2015
# 4             64.380952  2014/2015
# ..                  ...        ...
# 681           66.166667  2020/2021
# 682           66.450000  2020/2021
# 683           64.650000  2020/2021
# 684           63.952381  2020/2021
# 685           64.190476  2020/2021
#
# [686 rows x 11 columns]

# %%
fifa_ags_ag_fit['agility_fitness_mean'] = fifa_ags_ag_fit.mean(axis=1)
fifa_ags_ag_fit
# Out:
#                    club_name       pace movement_acceleration mean  \
#                                    mean
# 0                 1. FC Köln  71.000000                  68.125000
# 1            1. FSV Mainz 05  74.333333                  71.850000
# 2                  AS Monaco  69.000000                  65.562500
# 3           AS Saint-Étienne  70.400000                  67.235294
# 4                    Arsenal  74.294118                  69.428571
# ..                       ...        ...                        ...
# 681            VfL Wolfsburg  70.866667                  66.000000
# 682            Villarreal CF  65.055556                  63.750000
# 683     West Bromwich Albion  68.666667                  67.000000
# 684          West Ham United  68.388889                  65.285714
# 685  Wolverhampton Wanderers  68.950000                  68.000000
#
#     movement_sprint_speed mean movement_agility mean movement_reactions mean  \
#
# 0                    68.562500             66.312500               66.812500
# 1                    73.000000             68.650000               67.250000
# 2                    65.500000             63.937500               69.625000
# 3                    67.705882             62.647059               66.764706
# 4                    68.428571             67.142857               68.809524
# ..                         ...                   ...                     ...
# 681                  65.277778             63.111111               69.888889
# 682                  62.600000             65.100000               68.950000
# 683                  65.400000             62.700000               64.100000
# 684                  63.809524             64.285714               65.809524
# 685                  68.666667             68.761905               66.619048
#
#     movement_balance mean power_jumping mean power_stamina mean  \
#
# 0               63.062500          69.250000          64.875000
# 1               66.700000          67.850000          64.850000
# 2               62.625000          68.187500          63.625000
# 3               62.705882          67.352941          68.588235
# 4               66.190476          61.476190          64.571429
# ..                    ...                ...                ...
# 681             62.444444          67.388889          64.055556
# 682             63.950000          66.600000          63.250000
# 683             64.000000          63.050000          64.000000
# 684             64.619048          65.047619          61.714286
# 685             68.285714          69.285714          68.095238
#
#     power_strength mean     Season agility_fitness_mean
#
# 0             69.250000  2014/2015            67.472222
# 1             65.850000  2014/2015            68.925926
# 2             71.500000  2014/2015            66.618056
# 3             70.470588  2014/2015            67.096732
# 4             64.380952  2014/2015            67.191410
# ..                  ...        ...                  ...
# 681           66.166667  2020/2021            66.133333
# 682           66.450000  2020/2021            65.078395
# 683           64.650000  2020/2021            64.840741
# 684           63.952381  2020/2021            64.768078
# 685           64.190476  2020/2021            67.872751
#
# [686 rows x 12 columns]

# %%
# Scoring (shooting,attacking_crossing, attacking_finishing, attacking_heading_accuracy, skill_fk_accuracy, 
#          power_shot_power, power_long_shots)

def scoring_column(fifas):
    years = ['2014/2015', "2015/2016", "2016/2017", "2017/2018", "2018/2019", "2019/2020", "2020/2021"]
    
    updated_fifas = []
    for i, season in enumerate(fifas):
        
        subs = season[(season['team_position'] == 'SUB')].index
        season.drop(subs, inplace=True)
        scoring = season.groupby('club_name').agg({'shooting': ['mean']})

        scoring['attacking_crossing mean'] = season.groupby('club_name').agg({'attacking_crossing': ['mean']})
        scoring['attacking_finishing mean'] = season.groupby('club_name').agg({'attacking_finishing': ['mean']})
        scoring['attacking_heading_accuracy mean'] = season.groupby('club_name').agg({'attacking_heading_accuracy': ['mean']})
        scoring['skill_fk_accuracy mean'] = season.groupby('club_name').agg({'skill_fk_accuracy': ['mean']})
        scoring['power_shot_power mean'] = season.groupby('club_name').agg({'power_shot_power': ['mean']})
        scoring['power_long_shots mean'] = season.groupby('club_name').agg({'power_long_shots': ['mean']})
      

        scoring['Season'] = years[i]

            
        
        updated_fifas.append(scoring)
    return updated_fifas

# %%
fifa_ags = scoring_column(new)

fifa_ags_scoring = fifa_ags[0].append(fifa_ags[1])
fifa_ags_scoring = fifa_ags_scoring.append(fifa_ags[2])
fifa_ags_scoring = fifa_ags_scoring.append(fifa_ags[3])
fifa_ags_scoring = fifa_ags_scoring.append(fifa_ags[4])
fifa_ags_scoring = fifa_ags_scoring.append(fifa_ags[5])
fifa_ags_scoring = fifa_ags_scoring.append(fifa_ags[6])
# fifa_ags_off.columns = ['defending_mean', 'season']
fifa_ags_scoring.index.name = 'club_name'
fifa_ags_scoring.reset_index(inplace=True)
fifa_ags_scoring
# Out:
# /Users/SirLawrenceKatz/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                    club_name   shooting attacking_crossing mean  \
#                                    mean
# 0                 1. FC Köln  55.285714               50.750000
# 1            1. FSV Mainz 05  57.166667               57.950000
# 2                  AS Monaco  60.076923               57.437500
# 3           AS Saint-Étienne  55.400000               56.352941
# 4                    Arsenal  58.000000               54.952381
# ..                       ...        ...                     ...
# 681            VfL Wolfsburg  61.466667               49.722222
# 682            Villarreal CF  58.055556               53.550000
# 683     West Bromwich Albion  49.500000               49.400000
# 684          West Ham United  54.055556               51.285714
# 685  Wolverhampton Wanderers  55.000000               57.523810
#
#     attacking_finishing mean attacking_heading_accuracy mean  \
#
# 0                  48.875000                       58.562500
# 1                  50.250000                       57.300000
# 2                  50.812500                       60.000000
# 3                  49.705882                       60.588235
# 4                  49.047619                       55.095238
# ..                       ...                             ...
# 681                50.333333                       52.722222
# 682                51.650000                       58.550000
# 683                44.250000                       53.500000
# 684                45.428571                       52.238095
# 685                50.619048                       54.666667
#
#     skill_fk_accuracy mean power_shot_power mean power_long_shots mean  \
#
# 0                43.625000             62.062500             49.437500
# 1                49.400000             62.500000             54.500000
# 2                50.875000             63.312500             52.687500
# 3                45.294118             57.529412             52.411765
# 4                47.571429             57.428571             50.904762
# ..                     ...                   ...                   ...
# 681              44.388889             66.277778             53.555556
# 682              45.300000             63.450000             53.900000
# 683              39.150000             53.250000             45.800000
# 684              41.904762             59.428571             48.476190
# 685              47.428571             62.333333             51.619048
#
#         Season
#
# 0    2014/2015
# 1    2014/2015
# 2    2014/2015
# 3    2014/2015
# 4    2014/2015
# ..         ...
# 681  2020/2021
# 682  2020/2021
# 683  2020/2021
# 684  2020/2021
# 685  2020/2021
#
# [686 rows x 9 columns]

# %%
fifa_ags_scoring['scoring_mean'] = fifa_ags_scoring.mean(axis=1)
fifa_ags_scoring
# Out:
#                    club_name   shooting attacking_crossing mean  \
#                                    mean
# 0                 1. FC Köln  55.285714               50.750000
# 1            1. FSV Mainz 05  57.166667               57.950000
# 2                  AS Monaco  60.076923               57.437500
# 3           AS Saint-Étienne  55.400000               56.352941
# 4                    Arsenal  58.000000               54.952381
# ..                       ...        ...                     ...
# 681            VfL Wolfsburg  61.466667               49.722222
# 682            Villarreal CF  58.055556               53.550000
# 683     West Bromwich Albion  49.500000               49.400000
# 684          West Ham United  54.055556               51.285714
# 685  Wolverhampton Wanderers  55.000000               57.523810
#
#     attacking_finishing mean attacking_heading_accuracy mean  \
#
# 0                  48.875000                       58.562500
# 1                  50.250000                       57.300000
# 2                  50.812500                       60.000000
# 3                  49.705882                       60.588235
# 4                  49.047619                       55.095238
# ..                       ...                             ...
# 681                50.333333                       52.722222
# 682                51.650000                       58.550000
# 683                44.250000                       53.500000
# 684                45.428571                       52.238095
# 685                50.619048                       54.666667
#
#     skill_fk_accuracy mean power_shot_power mean power_long_shots mean  \
#
# 0                43.625000             62.062500             49.437500
# 1                49.400000             62.500000             54.500000
# 2                50.875000             63.312500             52.687500
# 3                45.294118             57.529412             52.411765
# 4                47.571429             57.428571             50.904762
# ..                     ...                   ...                   ...
# 681              44.388889             66.277778             53.555556
# 682              45.300000             63.450000             53.900000
# 683              39.150000             53.250000             45.800000
# 684              41.904762             59.428571             48.476190
# 685              47.428571             62.333333             51.619048
#
#         Season scoring_mean
#
# 0    2014/2015    52.656888
# 1    2014/2015    55.580952
# 2    2014/2015    56.457418
# 3    2014/2015    53.897479
# 4    2014/2015    53.285714
# ..         ...          ...
# 681  2020/2021    54.066667
# 682  2020/2021    54.922222
# 683  2020/2021    47.835714
# 684  2020/2021    50.402494
# 685  2020/2021    54.170068
#
# [686 rows x 10 columns]

# %%
# Mentality (mentality_aggression, mentality_interceptions, mentality_positioning, mentality_vision, 
#            mentality_penalties)

def mentality_column(fifas):
    years = ['2014/2015', "2015/2016", "2016/2017", "2017/2018", "2018/2019", "2019/2020", "2020/2021"]
    
    updated_fifas = []
    for i, season in enumerate(fifas):
        
        subs = season[(season['team_position'] == 'SUB')].index
        season.drop(subs, inplace=True)
        mentality = season.groupby('club_name').agg({'mentality_aggression': ['mean']})

        mentality['mentality_interceptions mean'] = season.groupby('club_name').agg({'mentality_interceptions': ['mean']})
        mentality['mentality_positioning mean'] = season.groupby('club_name').agg({'mentality_positioning': ['mean']})
        mentality['mentality_vision mean'] = season.groupby('club_name').agg({'mentality_vision': ['mean']})
        mentality['mentality_penalties mean'] = season.groupby('club_name').agg({'mentality_penalties': ['mean']})
       
      

        mentality['Season'] = years[i]

            
        
        updated_fifas.append(mentality)
    return updated_fifas

# %%
fifa_ags = mentality_column(new)

fifa_ags_mentality = fifa_ags[0].append(fifa_ags[1])
fifa_ags_mentality = fifa_ags_mentality.append(fifa_ags[2])
fifa_ags_mentality = fifa_ags_mentality.append(fifa_ags[3])
fifa_ags_mentality = fifa_ags_mentality.append(fifa_ags[4])
fifa_ags_mentality = fifa_ags_mentality.append(fifa_ags[5])
fifa_ags_mentality = fifa_ags_mentality.append(fifa_ags[6])
# fifa_ags_off.columns = ['defending_mean', 'season']
fifa_ags_mentality.index.name = 'club_name'
fifa_ags_mentality.reset_index(inplace=True)
fifa_ags_mentality
# Out:
# /Users/SirLawrenceKatz/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                    club_name mentality_aggression  \
#                                              mean
# 0                 1. FC Köln            59.687500
# 1            1. FSV Mainz 05            54.200000
# 2                  AS Monaco            56.000000
# 3           AS Saint-Étienne            58.764706
# 4                    Arsenal            57.761905
# ..                       ...                  ...
# 681            VfL Wolfsburg            58.833333
# 682            Villarreal CF            59.050000
# 683     West Bromwich Albion            55.950000
# 684          West Ham United            60.095238
# 685  Wolverhampton Wanderers            63.047619
#
#     mentality_interceptions mean mentality_positioning mean  \
#
# 0                      47.500000                  52.750000
# 1                      50.650000                  54.950000
# 2                      52.750000                  55.562500
# 3                      52.647059                  51.588235
# 4                      48.809524                  54.666667
# ..                           ...                        ...
# 681                    46.222222                  53.222222
# 682                    53.350000                  53.400000
# 683                    46.300000                  49.000000
# 684                    49.333333                  51.428571
# 685                    54.095238                  55.761905
#
#     mentality_vision mean mentality_penalties mean     Season
#
# 0               51.312500                53.062500  2014/2015
# 1               55.250000                53.650000  2014/2015
# 2               58.125000                53.562500  2014/2015
# 3               57.000000                51.588235  2014/2015
# 4               57.047619                56.047619  2014/2015
# ..                    ...                      ...        ...
# 681             56.777778                49.388889  2020/2021
# 682             59.800000                49.750000  2020/2021
# 683             56.100000                48.550000  2020/2021
# 684             58.380952                47.952381  2020/2021
# 685             63.809524                52.142857  2020/2021
#
# [686 rows x 7 columns]

# %%
fifa_ags_mentality['mentality_mean'] = fifa_ags_mentality.mean(axis=1)
fifa_ags_mentality
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-332bdff6e36f> in <module>
# ----> 1 fifa_ags_mentality['mentality_mean'] = fifa_ags_mentality.mean(axis=1)
#       2 fifa_ags_mentality
#
# NameError: name 'fifa_ags_mentality' is not defined

# %%
# Avg Nationality (most common nationality on team)

def team_nat_column(fifas):
    years = ['2014/2015', "2015/2016", "2016/2017", "2017/2018", "2018/2019", "2019/2020", "2020/2021"]
    
    updated_fifas = []
    for i, season in enumerate(fifas):
        
        subs = season[(season['team_position'] == 'SUB')].index
        season.drop(subs, inplace=True)
        team_nat = season.groupby('club_name').agg(pd.Series.mode)

        
#        source.groupby(['Country','City']).agg(lambda x:x.value_counts().index[0])
      

        team_nat['Season'] = years[i]

            
        
        updated_fifas.append(team_nat)
    return updated_fifas

# %%
fifa_ags = team_nat_column(new)

fifa_ags_team_nat = fifa_ags[0].append(fifa_ags[1])
fifa_ags_team_nat = fifa_ags_team_nat.append(fifa_ags[2])
fifa_ags_team_nat = fifa_ags_team_nat.append(fifa_ags[3])
fifa_ags_team_nat = fifa_ags_team_nat.append(fifa_ags[4])
fifa_ags_team_nat = fifa_ags_team_nat.append(fifa_ags[5])
fifa_ags_team_nat = fifa_ags_team_nat.append(fifa_ags[6])
# fifa_ags_team_nat.columns = ['team_nationality', 'season']
fifa_ags_team_nat.index.name = 'club_name'
fifa_ags_team_nat.reset_index(inplace=True)

fifa_ags_team_nat = fifa_ags_team_nat[['Season','club_name', 'nationality']].copy()
fifa_ags_team_nat
# Out:
# /Users/SirLawrenceKatz/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#         Season                club_name nationality
# 0    2014/2015               1. FC Köln     Germany
# 1    2014/2015          1. FSV Mainz 05     Germany
# 2    2014/2015                AS Monaco      France
# 3    2014/2015         AS Saint-Étienne      France
# 4    2014/2015                  Arsenal     England
# ..         ...                      ...         ...
# 681  2020/2021            VfL Wolfsburg     Germany
# 682  2020/2021            Villarreal CF       Spain
# 683  2020/2021     West Bromwich Albion     England
# 684  2020/2021          West Ham United     England
# 685  2020/2021  Wolverhampton Wanderers     England
#
# [686 rows x 3 columns]

# %%
# Goalkeeping -only GKs (gk_diving, gk_handling, gk_kicking, gk_reflexes, gk_speed, gk_positioning, 
#                        goalkeeping_diving, goalkeeping_handling, goalkeeping_kicking, goalkeeping_positioning, 
#                        goalkeeping_reflexes)

def goalkeeping_column(fifas):
    years = ['2014/2015', "2015/2016", "2016/2017", "2017/2018", "2018/2019", "2019/2020", "2020/2021"]
    
    updated_fifas = []
    for i, season in enumerate(fifas):
        
        subs = season[(season['team_position'] == 'SUB')].index
        season.drop(subs, inplace=True)
        goalkeeping = season.groupby(['club_name', 'team_position']).agg({'gk_diving': ['mean']})

#         goalkeeping['gk_handling mean'] = season.groupby('club_name').agg({'gk_handling': ['mean']})
        goalkeeping['gk_kicking mean'] = season.groupby(['club_name', 'team_position']).agg({'gk_kicking': ['mean']})
        goalkeeping['gk_reflexes mean'] = season.groupby(['club_name', 'team_position']).agg({'gk_reflexes': ['mean']})
        goalkeeping['gk_speed mean'] = season.groupby(['club_name', 'team_position']).agg({'gk_speed': ['mean']})
#         goalkeeping['gk_positioning mean'] = season.groupby('club_name').agg({'gk_positioning': ['mean']})
        goalkeeping['goalkeeping_diving mean'] = season.groupby(['club_name', 'team_position']).agg({'goalkeeping_diving': ['mean']})
#         goalkeeping['goalkeeping_handling mean'] = season.groupby(['club_name', 'team_position']).agg({'goalkeeping_handling': ['mean']})
        goalkeeping['goalkeeping_kicking mean'] = season.groupby(['club_name', 'team_position']).agg({'goalkeeping_kicking': ['mean']})
#         goalkeeping['goalkeeping_positioning mean'] = season.groupby(['club_name', 'team_position']).agg({'goalkeeping_positioning': ['mean']})
        goalkeeping['goalkeeping_reflexes mean'] = season.groupby(['club_name', 'team_position']).agg({'goalkeeping_reflexes': ['mean']})
      

        goalkeeping['Season'] = years[i]

            
        
        updated_fifas.append(goalkeeping)
    return updated_fifas

# %%
fifa_ags = goalkeeping_column(new)

fifa_ags_goalkeeping = fifa_ags[0].append(fifa_ags[1])
fifa_ags_goalkeeping = fifa_ags_goalkeeping.append(fifa_ags[2])
fifa_ags_goalkeeping = fifa_ags_goalkeeping.append(fifa_ags[3])
fifa_ags_goalkeeping = fifa_ags_goalkeeping.append(fifa_ags[4])
fifa_ags_goalkeeping = fifa_ags_goalkeeping.append(fifa_ags[5])
fifa_ags_goalkeeping = fifa_ags_goalkeeping.append(fifa_ags[6])
# fifa_ags_team_nat.columns = ['team_nationality', 'season']
fifa_ags_goalkeeping.index.name = 'club_name'
fifa_ags_goalkeeping.reset_index(inplace=True)

# fifa_ags_goalkeeping = fifa_ags_team_nat[['Season','club_name', 'nationality']].copy()
fifa_ags_goalkeeping = fifa_ags_goalkeeping.loc[fifa_ags_goalkeeping['team_position'] == 'GK']
fifa_ags_goalkeeping
# Out:
# /Users/SirLawrenceKatz/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                     club_name team_position gk_diving gk_kicking mean  \
#                                                  mean
# 1                  1. FC Köln            GK      73.0            74.0
# 13            1. FSV Mainz 05            GK      75.0            74.0
# 25                  AS Monaco            GK      76.0            78.0
# 37           AS Saint-Étienne            GK      82.0            77.0
# 49                    Arsenal            GK      83.0            70.0
# ...                       ...           ...       ...             ...
# 8144            VfL Wolfsburg            GK      83.0            80.0
# 8155            Villarreal CF            GK      85.0            77.0
# 8168     West Bromwich Albion            GK      79.0            70.0
# 8180          West Ham United            GK      80.0            70.0
# 8192  Wolverhampton Wanderers            GK      84.0            77.0
#
#      gk_reflexes mean gk_speed mean goalkeeping_diving mean  \
#
# 1                77.0          48.0                    73.0
# 13               77.0          49.0                    75.0
# 25               76.0          53.0                    76.0
# 37               86.0          54.0                    82.0
# 49               84.0          45.0                    83.0
# ...               ...           ...                     ...
# 8144             84.0          45.0                    83.0
# 8155             88.0          54.0                    85.0
# 8168             77.0          41.0                    79.0
# 8180             82.0          48.0                    80.0
# 8192             83.0          55.0                    84.0
#
#      goalkeeping_kicking mean goalkeeping_reflexes mean     Season
#
# 1                        74.0                      77.0  2014/2015
# 13                       74.0                      77.0  2014/2015
# 25                       78.0                      76.0  2014/2015
# 37                       77.0                      86.0  2014/2015
# 49                       70.0                      84.0  2014/2015
# ...                       ...                       ...        ...
# 8144                     80.0                      84.0  2020/2021
# 8155                     77.0                      88.0  2020/2021
# 8168                     70.0                      77.0  2020/2021
# 8180                     70.0                      82.0  2020/2021
# 8192                     77.0                      83.0  2020/2021
#
# [686 rows x 10 columns]

# %%
fifa_ags_goalkeeping['goalkeeping_mean'] = fifa_ags_goalkeeping.mean(axis=1)
fifa_ags_goalkeeping
# Out:
#                     club_name team_position gk_diving gk_kicking mean  \
#                                                  mean
# 1                  1. FC Köln            GK      73.0            74.0
# 13            1. FSV Mainz 05            GK      75.0            74.0
# 25                  AS Monaco            GK      76.0            78.0
# 37           AS Saint-Étienne            GK      82.0            77.0
# 49                    Arsenal            GK      83.0            70.0
# ...                       ...           ...       ...             ...
# 8144            VfL Wolfsburg            GK      83.0            80.0
# 8155            Villarreal CF            GK      85.0            77.0
# 8168     West Bromwich Albion            GK      79.0            70.0
# 8180          West Ham United            GK      80.0            70.0
# 8192  Wolverhampton Wanderers            GK      84.0            77.0
#
#      gk_reflexes mean gk_speed mean goalkeeping_diving mean  \
#
# 1                77.0          48.0                    73.0
# 13               77.0          49.0                    75.0
# 25               76.0          53.0                    76.0
# 37               86.0          54.0                    82.0
# 49               84.0          45.0                    83.0
# ...               ...           ...                     ...
# 8144             84.0          45.0                    83.0
# 8155             88.0          54.0                    85.0
# 8168             77.0          41.0                    79.0
# 8180             82.0          48.0                    80.0
# 8192             83.0          55.0                    84.0
#
#      goalkeeping_kicking mean goalkeeping_reflexes mean     Season  \
#
# 1                        74.0                      77.0  2014/2015
# 13                       74.0                      77.0  2014/2015
# 25                       78.0                      76.0  2014/2015
# 37                       77.0                      86.0  2014/2015
# 49                       70.0                      84.0  2014/2015
# ...                       ...                       ...        ...
# 8144                     80.0                      84.0  2020/2021
# 8155                     77.0                      88.0  2020/2021
# 8168                     70.0                      77.0  2020/2021
# 8180                     70.0                      82.0  2020/2021
# 8192                     77.0                      83.0  2020/2021
#
#      goalkeeping_mean
#
# 1           70.857143
# 13          71.571429
# 25          73.285714
# 37          77.714286
# 49          74.142857
# ...               ...
# 8144        77.000000
# 8155        79.142857
# 8168        70.428571
# 8180        73.142857
# 8192        77.571429
#
# [686 rows x 11 columns]

# %%
fifa_ags_goalkeeping1 = fifa_ags_goalkeeping[['Season','club_name', 'goalkeeping_mean']].copy()
fifa_ags_team_nat

fifa_ags_mentality1 = fifa_ags_mentality[['Season','club_name', 'mentality_mean']].copy()

fifa_ags_scoring1 = fifa_ags_scoring[['Season','club_name', 'scoring_mean']].copy()

fifa_ags_ag_fit1 = fifa_ags_ag_fit[['Season','club_name', 'agility_fitness_mean']].copy()

fifa_ags_off1 = fifa_ags_off[['Season','club_name', 'offense_mean']].copy()

fifa_ags_def1 = fifa_ags_def[['Season','club_name', 'defense_mean', 'overall']].copy()

fifa_ags_def1
# Out:
#         Season                club_name  defense_mean    overall
# 0    2014/2015               1. FC Köln     60.513393  68.812500
# 1    2014/2015          1. FSV Mainz 05     60.138889  68.000000
# 2    2014/2015                AS Monaco     64.973558  72.562500
# 3    2014/2015         AS Saint-Étienne     63.670588  69.941176
# 4    2014/2015                  Arsenal     63.815126  71.571429
# ..         ...                      ...           ...        ...
# 681  2020/2021            VfL Wolfsburg     62.300000  71.000000
# 682  2020/2021            Villarreal CF     66.277778  73.000000
# 683  2020/2021     West Bromwich Albion     59.963889  67.650000
# 684  2020/2021          West Ham United     62.662698  69.380952
# 685  2020/2021  Wolverhampton Wanderers     62.894048  70.238095
#
# [686 rows x 4 columns]

# %%
fifa_agg_stats = pd.merge(fifa_ags_mentality1, fifa_ags_scoring1, how='left', 
                          on=['Season', 'club_name'])
fifa_agg_stats1 = pd.merge(fifa_agg_stats, fifa_ags_ag_fit1, how='left', 
                          left_on=['Season', 'club_name'], right_on = ['Season', 'club_name'])
fifa_agg_stats2 = pd.merge(fifa_agg_stats1, fifa_ags_off1, how='left', 
                          left_on=['Season', 'club_name'], right_on = ['Season', 'club_name'])
fifa_agg_stats4 = pd.merge(fifa_agg_stats2, fifa_ags_def1, how='left', on=['Season', 'club_name'])
# fifa_agg_stats3 = pd.merge(fifa_agg_stats2, fifa_ags_def1, how='left', 
#                           left_on=['Season', 'club_name'], right_on = ['Season', 'club_name'])
fifa_agg_stats4.columns = ['Season', 'club_name', 'ss', 'cn', 'mentality_mean', 'scoring_mean', 'agility_fitness_mean',
                          'offense_mean', 'defense_mean', 'overall']
# fifa_ags_def.columns = ['defending_mean', 'Season']
fifa_agg_stats4
# Out:
# /Users/SirLawrenceKatz/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py:648: UserWarning: merging between different levels can give an unintended result (2 levels on the left,1 on the right)
#   warnings.warn(msg, UserWarning)
#         Season                club_name         ss                       cn  \
# 0    2014/2015               1. FC Köln  2014/2015               1. FC Köln
# 1    2014/2015          1. FSV Mainz 05  2014/2015          1. FSV Mainz 05
# 2    2014/2015                AS Monaco  2014/2015                AS Monaco
# 3    2014/2015         AS Saint-Étienne  2014/2015         AS Saint-Étienne
# 4    2014/2015                  Arsenal  2014/2015                  Arsenal
# ..         ...                      ...        ...                      ...
# 681  2020/2021            VfL Wolfsburg  2020/2021            VfL Wolfsburg
# 682  2020/2021            Villarreal CF  2020/2021            Villarreal CF
# 683  2020/2021     West Bromwich Albion  2020/2021     West Bromwich Albion
# 684  2020/2021          West Ham United  2020/2021          West Ham United
# 685  2020/2021  Wolverhampton Wanderers  2020/2021  Wolverhampton Wanderers
#
#      mentality_mean  scoring_mean  agility_fitness_mean  offense_mean  \
# 0         52.862500     52.656888             67.472222     55.780612
# 1         53.740000     55.580952             68.925926     59.530952
# 2         55.200000     56.457418             66.618056     61.195742
# 3         54.317647     53.897479             67.096732     58.581513
# 4         54.866667     53.285714             67.191410     59.398159
# ..              ...           ...                   ...           ...
# 681       52.888889     54.066667             66.133333     56.588889
# 682       55.070000     54.922222             65.078395     60.015873
# 683       51.180000     47.835714             64.840741     54.423016
# 684       53.438095     50.402494             64.768078     55.942177
# 685       57.771429     54.170068             67.872751     60.090136
#
#      defense_mean    overall
# 0       60.513393  68.812500
# 1       60.138889  68.000000
# 2       64.973558  72.562500
# 3       63.670588  69.941176
# 4       63.815126  71.571429
# ..            ...        ...
# 681     62.300000  71.000000
# 682     66.277778  73.000000
# 683     59.963889  67.650000
# 684     62.662698  69.380952
# 685     62.894048  70.238095
#
# [686 rows x 10 columns]

# %%
fifa_agg_stats5 = fifa_agg_stats4[['Season','club_name', 'offense_mean', 'defense_mean', 'mentality_mean', 
                                  'scoring_mean', 'agility_fitness_mean', 'overall']].copy()
fifa_agg_stats5
# Out:
#         Season                club_name  offense_mean  defense_mean  \
# 0    2014/2015               1. FC Köln     55.780612     60.513393
# 1    2014/2015          1. FSV Mainz 05     59.530952     60.138889
# 2    2014/2015                AS Monaco     61.195742     64.973558
# 3    2014/2015         AS Saint-Étienne     58.581513     63.670588
# 4    2014/2015                  Arsenal     59.398159     63.815126
# ..         ...                      ...           ...           ...
# 681  2020/2021            VfL Wolfsburg     56.588889     62.300000
# 682  2020/2021            Villarreal CF     60.015873     66.277778
# 683  2020/2021     West Bromwich Albion     54.423016     59.963889
# 684  2020/2021          West Ham United     55.942177     62.662698
# 685  2020/2021  Wolverhampton Wanderers     60.090136     62.894048
#
#      mentality_mean  scoring_mean  agility_fitness_mean    overall
# 0         52.862500     52.656888             67.472222  68.812500
# 1         53.740000     55.580952             68.925926  68.000000
# 2         55.200000     56.457418             66.618056  72.562500
# 3         54.317647     53.897479             67.096732  69.941176
# 4         54.866667     53.285714             67.191410  71.571429
# ..              ...           ...                   ...        ...
# 681       52.888889     54.066667             66.133333  71.000000
# 682       55.070000     54.922222             65.078395  73.000000
# 683       51.180000     47.835714             64.840741  67.650000
# 684       53.438095     50.402494             64.768078  69.380952
# 685       57.771429     54.170068             67.872751  70.238095
#
# [686 rows x 8 columns]

# %%
games_15_21
# Out:
#           Season             Datetime                    League  \
# 4      2020/2021  2021-02-08 20:00:00            Premier League
# 5      2020/2021  2021-02-08 20:00:00  La Liga Primera Division
# 19     2020/2021  2021-02-07 20:00:00            Le Championnat
# 20     2020/2021  2021-02-07 20:00:00  La Liga Primera Division
# 23     2020/2021  2021-02-07 19:45:00                   Serie A
# ...          ...                  ...                       ...
# 77246  2014/2015  2014-08-09 00:00:00            Le Championnat
# 77256  2014/2015  2014-08-09 00:00:00            Premier League
# 77258  2014/2015  2014-08-09 00:00:00            Le Championnat
# 77259  2014/2015  2014-08-09 00:00:00            Le Championnat
# 77296  2014/2015  2014-08-08 00:00:00            Le Championnat
#
#                        HomeTeam                AwayTeam  FTHG  FTAG  Hwinodds  \
# 4                  Leeds United          Crystal Palace     2     0      1.80
# 5               Atlético Madrid                RC Celta     2     2      1.60
# 19       Olympique de Marseille     Paris Saint-Germain     0     2      7.50
# 20                   Real Betis            FC Barcelona     2     3      5.75
# 23                        Lazio                Cagliari     1     0      1.36
# ...                         ...                     ...   ...   ...       ...
# 77246                  OGC Nice  Toulouse Football Club     3     2      2.63
# 77256                    Dundee              Kilmarnock     1     1      2.38
# 77258   Sporting Club de Bastia  Olympique de Marseille     3     3      3.90
# 77259  Évian Thonon Gaillard FC     Stade Malherbe Caen     0     3      2.38
# 77296            Stade de Reims     Paris Saint-Germain     2     2      9.50
#
#        Dodds  Awinodds
# 4        3.8      4.20
# 5        3.6      6.50
# 19       5.0      1.40
# 20       4.6      1.50
# 23       5.0      8.00
# ...      ...       ...
# 77246    3.1      2.75
# 77256    3.2      3.00
# 77258    3.1      2.05
# 77259    3.2      3.00
# 77296    4.5      1.36
#
# [13395 rows x 10 columns]

# %%
def win_loss_tie1(master):
    new_list = []
    for index, row in master.iterrows():
        if (row['FTHG'] > row['FTAG']):
            new_list.append(3)
        if (row['FTHG'] == row['FTAG']):
            new_list.append(1)
        if (row['FTHG'] < row['FTAG']):
            new_list.append(0)
    return new_list

# %%
win_lost_tie = win_loss_tie1(games_15_21)

# %%
games_15_21['win3_tie1_loss0'] = win_lost_tie

# %%
games_15_21
# Out:
#           Season             Datetime                    League  \
# 4      2020/2021  2021-02-08 20:00:00            Premier League
# 5      2020/2021  2021-02-08 20:00:00  La Liga Primera Division
# 19     2020/2021  2021-02-07 20:00:00            Le Championnat
# 20     2020/2021  2021-02-07 20:00:00  La Liga Primera Division
# 23     2020/2021  2021-02-07 19:45:00                   Serie A
# ...          ...                  ...                       ...
# 77246  2014/2015  2014-08-09 00:00:00            Le Championnat
# 77256  2014/2015  2014-08-09 00:00:00            Premier League
# 77258  2014/2015  2014-08-09 00:00:00            Le Championnat
# 77259  2014/2015  2014-08-09 00:00:00            Le Championnat
# 77296  2014/2015  2014-08-08 00:00:00            Le Championnat
#
#                        HomeTeam                AwayTeam  FTHG  FTAG  Hwinodds  \
# 4                  Leeds United          Crystal Palace     2     0      1.80
# 5               Atlético Madrid                RC Celta     2     2      1.60
# 19       Olympique de Marseille     Paris Saint-Germain     0     2      7.50
# 20                   Real Betis            FC Barcelona     2     3      5.75
# 23                        Lazio                Cagliari     1     0      1.36
# ...                         ...                     ...   ...   ...       ...
# 77246                  OGC Nice  Toulouse Football Club     3     2      2.63
# 77256                    Dundee              Kilmarnock     1     1      2.38
# 77258   Sporting Club de Bastia  Olympique de Marseille     3     3      3.90
# 77259  Évian Thonon Gaillard FC     Stade Malherbe Caen     0     3      2.38
# 77296            Stade de Reims     Paris Saint-Germain     2     2      9.50
#
#        Dodds  Awinodds  win3_tie1_loss0
# 4        3.8      4.20                3
# 5        3.6      6.50                1
# 19       5.0      1.40                0
# 20       4.6      1.50                0
# 23       5.0      8.00                3
# ...      ...       ...              ...
# 77246    3.1      2.75                3
# 77256    3.2      3.00                1
# 77258    3.1      2.05                1
# 77259    3.2      3.00                0
# 77296    4.5      1.36                1
#
# [13395 rows x 11 columns]

# %%
# DataFrame.merge(right, how='inner', on=None, left_on=None, right_on=None, left_index=False, 
#                 right_index=False, sort=False, suffixes=('_H', None), copy=True, indicator=False, 
#                 validate=None)[source]
# fifa_agg_stats1 = pd.merge(fifa_agg_stats, fifa_ags_ag_fit1, how='left', 
#                           left_on=['Season', 'club_name'], right_on = ['Season', 'club_name'])

combo_final2 = pd.merge(games_15_21, fifa_agg_stats5, how='left', left_on=['Season', 'HomeTeam'], 
                        right_on = ['Season', 'club_name'])
combo_final2
# Out:
#           Season             Datetime                    League  \
# 0      2020/2021  2021-02-08 20:00:00            Premier League
# 1      2020/2021  2021-02-08 20:00:00  La Liga Primera Division
# 2      2020/2021  2021-02-07 20:00:00            Le Championnat
# 3      2020/2021  2021-02-07 20:00:00  La Liga Primera Division
# 4      2020/2021  2021-02-07 19:45:00                   Serie A
# ...          ...                  ...                       ...
# 13390  2014/2015  2014-08-09 00:00:00            Le Championnat
# 13391  2014/2015  2014-08-09 00:00:00            Premier League
# 13392  2014/2015  2014-08-09 00:00:00            Le Championnat
# 13393  2014/2015  2014-08-09 00:00:00            Le Championnat
# 13394  2014/2015  2014-08-08 00:00:00            Le Championnat
#
#                        HomeTeam                AwayTeam  FTHG  FTAG  Hwinodds  \
# 0                  Leeds United          Crystal Palace     2     0      1.80
# 1               Atlético Madrid                RC Celta     2     2      1.60
# 2        Olympique de Marseille     Paris Saint-Germain     0     2      7.50
# 3                    Real Betis            FC Barcelona     2     3      5.75
# 4                         Lazio                Cagliari     1     0      1.36
# ...                         ...                     ...   ...   ...       ...
# 13390                  OGC Nice  Toulouse Football Club     3     2      2.63
# 13391                    Dundee              Kilmarnock     1     1      2.38
# 13392   Sporting Club de Bastia  Olympique de Marseille     3     3      3.90
# 13393  Évian Thonon Gaillard FC     Stade Malherbe Caen     0     3      2.38
# 13394            Stade de Reims     Paris Saint-Germain     2     2      9.50
#
#        Dodds  Awinodds  win3_tie1_loss0                 club_name  \
# 0        3.8      4.20                3              Leeds United
# 1        3.6      6.50                1           Atlético Madrid
# 2        5.0      1.40                0    Olympique de Marseille
# 3        4.6      1.50                0                Real Betis
# 4        5.0      8.00                3                     Lazio
# ...      ...       ...              ...                       ...
# 13390    3.1      2.75                3                  OGC Nice
# 13391    3.2      3.00                1                       NaN
# 13392    3.1      2.05                1   Sporting Club de Bastia
# 13393    3.2      3.00                0  Évian Thonon Gaillard FC
# 13394    4.5      1.36                1            Stade de Reims
#
#        offense_mean  defense_mean  mentality_mean  scoring_mean  \
# 0         57.345149     61.491228       54.323810     52.736126
# 1         63.607590     65.882206       57.933333     59.547082
# 2         60.059434     65.281955       56.133333     54.680988
# 3         60.120848     63.231092       54.961905     54.877951
# 4         62.224132     69.001253       58.400000     56.366989
# ...             ...           ...             ...           ...
# 13390     54.034372     56.320802       50.761905     49.476907
# 13391           NaN           NaN             NaN           NaN
# 13392     55.900823     56.081454       52.657143     52.736842
# 13393     53.733083     59.476974       49.600000     47.499530
# 13394     57.676190     61.050980       53.035294     52.217927
#
#        agility_fitness_mean    overall
# 0                 65.607073  67.666667
# 1                 69.903091  76.238095
# 2                 66.559176  72.142857
# 3                 65.639900  72.285714
# 4                 68.164300  75.476190
# ...                     ...        ...
# 13390             64.741855  64.904762
# 13391                   NaN        NaN
# 13392             62.353662  64.952381
# 13393             61.020833  64.578947
# 13394             65.152941  67.235294
#
# [13395 rows x 18 columns]

# %%
combo_final = pd.merge(combo_final2, fifa_agg_stats5, how='left', left_on=['Season', 'AwayTeam'], 
                        right_on = ['Season', 'club_name'], suffixes = ('_H', '_A'))
combo_final.head(40)
# Out:
#        Season             Datetime                    League  \
# 0   2020/2021  2021-02-08 20:00:00            Premier League
# 1   2020/2021  2021-02-08 20:00:00  La Liga Primera Division
# 2   2020/2021  2021-02-07 20:00:00            Le Championnat
# 3   2020/2021  2021-02-07 20:00:00  La Liga Primera Division
# 4   2020/2021  2021-02-07 19:45:00                   Serie A
# 5   2020/2021  2021-02-07 19:15:00            Premier League
# 6   2020/2021  2021-02-07 17:30:00  La Liga Primera Division
# 7   2020/2021  2021-02-07 17:00:00                   Serie A
# 8   2020/2021  2021-02-07 16:30:00            Premier League
# 9   2020/2021  2021-02-07 16:00:00            Le Championnat
# 10  2020/2021  2021-02-07 15:15:00  La Liga Primera Division
# 11  2020/2021  2021-02-07 14:30:00              Bundesliga 1
# 12  2020/2021  2021-02-07 14:00:00            Le Championnat
# 13  2020/2021  2021-02-07 14:00:00            Le Championnat
# 14  2020/2021  2021-02-07 14:00:00                   Serie A
# 15  2020/2021  2021-02-07 14:00:00            Premier League
# 16  2020/2021  2021-02-07 14:00:00            Le Championnat
# 17  2020/2021  2021-02-07 14:00:00                   Serie A
# 18  2020/2021  2021-02-07 14:00:00            Le Championnat
# 19  2020/2021  2021-02-07 13:00:00  La Liga Primera Division
# 20  2020/2021  2021-02-07 12:00:00            Premier League
# 21  2020/2021  2021-02-07 12:00:00            Premier League
# 22  2020/2021  2021-02-07 12:00:00            Le Championnat
# 23  2020/2021  2021-02-07 11:30:00                   Serie A
# 24  2020/2021  2021-02-06 20:00:00  La Liga Primera Division
# 25  2020/2021  2021-02-06 20:00:00            Le Championnat
# 26  2020/2021  2021-02-06 20:00:00            Premier League
# 27  2020/2021  2021-02-06 19:45:00                   Serie A
# 28  2020/2021  2021-02-06 18:00:00            Le Championnat
# 29  2020/2021  2021-02-06 17:30:00  La Liga Primera Division
# 30  2020/2021  2021-02-06 17:30:00            Premier League
# 31  2020/2021  2021-02-06 17:30:00              Bundesliga 1
# 32  2020/2021  2021-02-06 17:00:00                   Serie A
# 33  2020/2021  2021-02-06 16:00:00            Le Championnat
# 34  2020/2021  2021-02-06 15:15:00  La Liga Primera Division
# 35  2020/2021  2021-02-06 15:00:00            Premier League
# 36  2020/2021  2021-02-06 15:00:00            Premier League
# 37  2020/2021  2021-02-06 15:00:00            Premier League
# 38  2020/2021  2021-02-06 15:00:00            Premier League
# 39  2020/2021  2021-02-06 15:00:00            Premier League
#
#                     HomeTeam                  AwayTeam  FTHG  FTAG  Hwinodds  \
# 0               Leeds United            Crystal Palace     2     0      1.80
# 1            Atlético Madrid                  RC Celta     2     2      1.60
# 2     Olympique de Marseille       Paris Saint-Germain     0     2      7.50
# 3                 Real Betis              FC Barcelona     2     3      5.75
# 4                      Lazio                  Cagliari     1     0      1.36
# 5           Sheffield United                   Chelsea     1     2      7.00
# 6                 CA Osasuna                  SD Eibar     2     1      2.55
# 7                      Parma                   Bologna     0     3      3.20
# 8                  Liverpool           Manchester City     1     4      3.40
# 9                  FC Nantes                LOSC Lille     0     2      4.50
# 10   Athletic Club de Bilbao               Valencia CF     1     1      2.15
# 11       TSG 1899 Hoffenheim       Eintracht Frankfurt     1     3      2.90
# 12           Montpellier HSC                 Dijon FCO     4     2      1.66
# 13          AS Saint-Étienne                   FC Metz     1     0      2.05
# 14                     Milan                   Crotone     4     0      1.22
# 15   Wolverhampton Wanderers            Leicester City     0     0      3.50
# 16                  OGC Nice                Angers SCO     3     0      2.70
# 17                   Udinese                    Verona     2     0      2.30
# 18           Nîmes Olympique                 AS Monaco     3     4      7.00
# 19             Real Sociedad                  Cádiz CF     4     1      1.45
# 20         Tottenham Hotspur      West Bromwich Albion     2     0      1.45
# 21                  Hamilton       Queens Park Rangers     1     1     21.00
# 22         Stade Brestois 29  FC Girondins de Bordeaux     2     1      2.50
# 23                 Benevento                 Sampdoria     1     1      3.00
# 24                Sevilla FC                 Getafe CF     3     0      1.72
# 25       Racing Club de Lens          Stade Rennais FC     0     0      2.70
# 26         Manchester United                   Everton     3     3      1.53
# 27                     Genoa                    Napoli     2     1      5.00
# 28        Olympique Lyonnais      RC Strasbourg Alsace     3     0      1.45
# 29                  Elche CF             Villarreal CF     2     2      6.50
# 30                    Fulham           West Ham United     0     0      3.60
# 31  Borussia Mönchengladbach                1. FC Köln     1     2      1.45
# 32                  Juventus                      Roma     2     0      1.72
# 33                FC Lorient            Stade de Reims     1     0      2.50
# 34                 SD Huesca               Real Madrid     1     2      7.00
# 35               Ross County             Dundee United     0     2      2.37
# 36          Newcastle United               Southampton     3     2      3.00
# 37                   Burnley    Brighton & Hove Albion     1     1      3.60
# 38                 St Mirren                Kilmarnock     2     0      2.00
# 39                 Hibernian                  Aberdeen     2     0      2.50
#
#     Dodds  Awinodds  win3_tie1_loss0               club_name_H  \
# 0    3.80      4.20                3              Leeds United
# 1    3.60      6.50                1           Atlético Madrid
# 2    5.00      1.40                0    Olympique de Marseille
# 3    4.60      1.50                0                Real Betis
# 4    5.00      8.00                3                     Lazio
# 5    4.50      1.45                0          Sheffield United
# 6    3.00      3.00                3                CA Osasuna
# 7    3.30      2.30                0                     Parma
# 8    3.60      2.05                0                 Liverpool
# 9    3.50      1.80                0                 FC Nantes
# 10   3.20      3.60                1   Athletic Club de Bilbao
# 11   3.80      2.25                0       TSG 1899 Hoffenheim
# 12   4.00      5.00                3           Montpellier HSC
# 13   3.25      3.80                3          AS Saint-Étienne
# 14   6.50     13.00                3                     Milan
# 15   3.40      2.10                1   Wolverhampton Wanderers
# 16   3.20      2.70                3                  OGC Nice
# 17   3.10      3.30                3                   Udinese
# 18   5.00      1.40                0           Nîmes Olympique
# 19   4.20      8.00                3             Real Sociedad
# 20   4.50      7.00                3         Tottenham Hotspur
# 21   9.00      1.10                1                       NaN
# 22   3.25      2.90                3         Stade Brestois 29
# 23   3.25      2.40                1                 Benevento
# 24   3.60      4.75                3                Sevilla FC
# 25   3.20      2.70                1       Racing Club de Lens
# 26   4.20      6.00                1         Manchester United
# 27   3.90      1.66                3                     Genoa
# 28   4.50      7.00                3        Olympique Lyonnais
# 29   3.80      1.53                1                  Elche CF
# 30   3.50      2.05                1                    Fulham
# 31   4.50      6.50                0  Borussia Mönchengladbach
# 32   4.00      4.33                3                  Juventus
# 33   3.20      2.90                3                FC Lorient
# 34   4.50      1.44                0                 SD Huesca
# 35   3.25      2.90                0                       NaN
# 36   3.30      2.40                3          Newcastle United
# 37   3.10      2.20                1                   Burnley
# 38   3.30      3.75                3                       NaN
# 39   3.20      2.80                3                       NaN
#
#     offense_mean_H  defense_mean_H  mentality_mean_H  scoring_mean_H  \
# 0        57.345149       61.491228         54.323810       52.736126
# 1        63.607590       65.882206         57.933333       59.547082
# 2        60.059434       65.281955         56.133333       54.680988
# 3        60.120848       63.231092         54.961905       54.877951
# 4        62.224132       69.001253         58.400000       56.366989
# 5        54.322368       64.470395         51.547368       48.029605
# 6        57.435589       63.322807         52.052632       52.511779
# 7        55.894267       63.225329         51.421053       51.789004
# 8        65.498866       70.690476         60.428571       59.527211
# 9        56.282850       61.724311         51.800000       50.532402
# 10       61.700188       66.251645         55.273684       57.529135
# 11       54.683929       62.018750         49.890000       48.644643
# 12       59.006723       64.149020         54.776471       54.328291
# 13       55.204082       58.539683         50.533333       50.352608
# 14       62.876751       66.998366         59.522222       59.697479
# 15       60.090136       62.894048         57.771429       54.170068
# 16       61.132937       63.569444         55.411111       56.461310
# 17       58.300454       62.166667         53.523810       54.273243
# 18       58.983673       62.164286         55.400000       54.531973
# 19       59.397064       63.527569         53.647619       53.910491
# 20       63.360544       70.079365         59.533333       57.397959
# 21             NaN             NaN               NaN             NaN
# 22       58.153571       58.685417         52.825000       53.211310
# 23       55.544576       59.249373         52.409524       50.857859
# 24       62.587302       68.440476         57.580952       57.844671
# 25       54.515575       59.174185         50.171429       47.921590
# 26       63.780045       72.880952         60.638095       57.298186
# 27       58.724311       62.368421         54.800000       54.074472
# 28       59.928571       69.976923         55.800000       53.959341
# 29       54.580357       56.944444         50.755556       52.570437
# 30       56.627641       59.335840         53.304762       52.678840
# 31       62.475474       64.750627         57.000000       57.234873
# 32       63.813357       69.216718         60.126316       59.516586
# 33       55.717687       61.250000         51.971429       49.362245
# 34       58.476190       61.395833         53.955556       53.443452
# 35             NaN             NaN               NaN             NaN
# 36       59.534193       64.085213         55.676190       54.460795
# 37       58.203373       63.503472         55.455556       54.675595
# 38             NaN             NaN               NaN             NaN
# 39             NaN             NaN               NaN             NaN
#
#     agility_fitness_mean_H  overall_H               club_name_A  \
# 0                65.607073  67.666667            Crystal Palace
# 1                69.903091  76.238095                  RC Celta
# 2                66.559176  72.142857       Paris Saint-Germain
# 3                65.639900  72.285714              FC Barcelona
# 4                68.164300  75.476190                  Cagliari
# 5                63.451023  69.315789                   Chelsea
# 6                64.198441  70.578947                  SD Eibar
# 7                64.520102  70.263158                   Bologna
# 8                71.285714  79.380952           Manchester City
# 9                62.838207  67.238095                LOSC Lille
# 10               68.589912  73.315789               Valencia CF
# 11               62.161111  69.850000       Eintracht Frankfurt
# 12               64.569063  70.764706                 Dijon FCO
# 13               63.138448  67.190476                   FC Metz
# 14               68.611111  75.055556                   Crotone
# 15               67.872751  70.238095            Leicester City
# 16               66.680556  71.888889                Angers SCO
# 17               64.276896  70.333333                       NaN
# 18               64.171958  69.400000                 AS Monaco
# 19               65.785854  72.476190                  Cádiz CF
# 20               68.581129  76.047619      West Bromwich Albion
# 21                     NaN        NaN                       NaN
# 22               65.059259  68.437500  FC Girondins de Bordeaux
# 23               64.409914  66.761905                 Sampdoria
# 24               65.920635  75.047619                 Getafe CF
# 25               63.894180  66.190476          Stade Rennais FC
# 26               69.925044  77.761905                   Everton
# 27               63.262322  70.000000                    Napoli
# 28               67.572650  76.153846      RC Strasbourg Alsace
# 29               60.558642  64.888889             Villarreal CF
# 30               66.403787  67.619048           West Ham United
# 31               67.810081  73.238095                1. FC Köln
# 32               67.694530  76.315789                      Roma
# 33               65.022487  68.500000            Stade de Reims
# 34               62.925154  68.666667               Real Madrid
# 35                     NaN        NaN                       NaN
# 36               66.670008  72.380952               Southampton
# 37               64.951389  70.444444    Brighton & Hove Albion
# 38                     NaN        NaN                       NaN
# 39                     NaN        NaN                       NaN
#
#     offense_mean_A  defense_mean_A  mentality_mean_A  scoring_mean_A  \
# 0        56.190834       63.230576         54.714286       52.613677
# 1        57.724669       62.479950         53.904762       52.045829
# 2        66.321569       70.350980         61.952941       58.698599
# 3        67.651701       67.301190         61.571429       60.918367
# 4        62.194737       63.244737         58.070000       59.260902
# 5        67.813946       74.227381         64.219048       60.358844
# 6        58.323413       61.486111         53.000000       54.109127
# 7        57.007937       65.492063         52.571429       50.492063
# 8        64.610097       68.340852         59.152381       58.346223
# 9        56.145005       61.107769         52.457143       50.479055
# 10       61.500895       64.590226         57.780952       58.553527
# 11       58.348789       66.137427         57.221053       55.279031
# 12       59.337415       61.797619         56.240000       54.097959
# 13       56.396032       60.111111         52.010000       49.682540
# 14       51.693161       55.607769         49.019048       48.829932
# 15       63.461869       68.711779         61.000000       58.405657
# 16       55.325456       61.498747         52.504762       50.728607
# 17             NaN             NaN               NaN             NaN
# 18       61.645542       66.365915         57.638095       54.721446
# 19       56.561224       61.261905         52.714286       54.617914
# 20       54.423016       59.963889         51.180000       47.835714
# 21             NaN             NaN               NaN             NaN
# 22       55.349940       61.911765         50.800000       50.149460
# 23       58.146825       63.711806         54.188889       53.237103
# 24       55.430172       66.018207         51.990476       49.924370
# 25       57.473923       63.480159         53.676190       52.522676
# 26       63.830290       66.235589         60.476190       60.117436
# 27       64.878625       66.803258         59.438095       58.950233
# 28       59.761905       66.850000         56.350000       53.914286
# 29       60.015873       66.277778         55.070000       54.922222
# 30       55.942177       62.662698         53.438095       50.402494
# 31       55.158730       62.416667         51.100000       50.974206
# 32       58.657231       65.193498         56.000000       53.552853
# 33       55.393849       60.225694         52.044444       51.067460
# 34       64.787815       66.792647         57.800000       60.237815
# 35             NaN             NaN               NaN             NaN
# 36       59.618367       63.167857         56.533333       54.250680
# 37       56.298186       62.670635         50.685714       50.070295
# 38             NaN             NaN               NaN             NaN
# 39             NaN             NaN               NaN             NaN
#
#     agility_fitness_mean_A  overall_A
# 0                63.167363  69.619048
# 1                65.495684  69.380952
# 2                72.681917  79.235294
# 3                72.543915  77.952381
# 4                64.462573  70.700000
# 5                70.265344  78.904762
# 6                62.012346  70.222222
# 7                63.517637  70.095238
# 8                70.486772  76.523810
# 9                64.642439  68.952381
# 10               66.712615  72.285714
# 11               65.923977  71.052632
# 12               65.198942  69.666667
# 13               65.855556  69.000000
# 14               58.843219  62.952381
# 15               66.954330  75.476190
# 16               60.996101  67.523810
# 17                     NaN        NaN
# 18               69.608744  74.047619
# 19               67.079365  69.523810
# 20               64.840741  67.650000
# 21                     NaN        NaN
# 22               63.660598  69.823529
# 23               63.695216  70.111111
# 24               61.596950  70.095238
# 25               65.036155  70.571429
# 26               67.549429  74.523810
# 27               68.114731  76.238095
# 28               65.712963  75.000000
# 29               65.078395  73.000000
# 30               64.768078  69.380952
# 31               64.283179  68.833333
# 32               64.939800  72.210526
# 33               64.351852  69.888889
# 34               69.625490  78.350000
# 35                     NaN        NaN
# 36               66.223810  71.285714
# 37               64.096120  69.285714
# 38                     NaN        NaN
# 39                     NaN        NaN

# %%
sum([True for idx,row in combo_final.iterrows() if any(row.isnull())])
# Out:
# 2276

# %%
combo_final1 = combo_final.dropna(axis=0)
combo_final1.head(3)
# Out:
#       Season             Datetime                    League  \
# 0  2020/2021  2021-02-08 20:00:00            Premier League
# 1  2020/2021  2021-02-08 20:00:00  La Liga Primera Division
# 2  2020/2021  2021-02-07 20:00:00            Le Championnat
#
#                  HomeTeam             AwayTeam  FTHG  FTAG  Hwinodds  Dodds  \
# 0            Leeds United       Crystal Palace     2     0       1.8    3.8
# 1         Atlético Madrid             RC Celta     2     2       1.6    3.6
# 2  Olympique de Marseille  Paris Saint-Germain     0     2       7.5    5.0
#
#    Awinodds  win3_tie1_loss0             club_name_H  offense_mean_H  \
# 0       4.2                3            Leeds United       57.345149
# 1       6.5                1         Atlético Madrid       63.607590
# 2       1.4                0  Olympique de Marseille       60.059434
#
#    defense_mean_H  mentality_mean_H  scoring_mean_H  agility_fitness_mean_H  \
# 0       61.491228         54.323810       52.736126               65.607073
# 1       65.882206         57.933333       59.547082               69.903091
# 2       65.281955         56.133333       54.680988               66.559176
#
#    overall_H          club_name_A  offense_mean_A  defense_mean_A  \
# 0  67.666667       Crystal Palace       56.190834       63.230576
# 1  76.238095             RC Celta       57.724669       62.479950
# 2  72.142857  Paris Saint-Germain       66.321569       70.350980
#
#    mentality_mean_A  scoring_mean_A  agility_fitness_mean_A  overall_A
# 0         54.714286       52.613677               63.167363  69.619048
# 1         53.904762       52.045829               65.495684  69.380952
# 2         61.952941       58.698599               72.681917  79.235294

# %%
combo_final3 = combo_final1.iloc[::-1]
combo_final3.to_pickle("./model_table.pkl")

# %% [markdown]
# ## Create Power_IDX Column
